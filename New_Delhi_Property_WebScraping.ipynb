# %%
import requests
from bs4 import BeautifulSoup
import urllib
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from http_request_randomizer.requests.proxy.requestProxy import RequestProxy
import pandas as pd

# %%
link="https://www.propertiesguru.com/residential-search/2bhk-residential_apartment_flat-for-sale-in-new_delhi"
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import SessionNotCreatedException

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(link)
initial_value=0
next_value=500
#driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
while next_value<30000:
    driver.execute_script("window.scrollTo({},{});".format(initial_value, next_value))
  
    initial_value=next_value
    next_value+=300
# Out:
# [WDM] - Current google-chrome version is 91.0.4472
# [WDM] - Get LATEST driver version for 91.0.4472
# [WDM] - Driver [C:\Users\hp\.wdm\drivers\chromedriver\win32\91.0.4472.101\chromedriver.exe] found in cache

# %%
html = driver.page_source
soup = BeautifulSoup(html)
soup
# Out:
# <html lang="en-US"><head>
# <meta content="notranslate" name="google"/>
# <link href="https://www.propertiesguru.com/media/images/favicon.png" rel="icon" sizes="16x16" type="image/png"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>2 BHK Apartment / Flat in New Delhi | Residential Apartment / Flat for sale in New Delhi</title>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/icon-font.min.css" rel="stylesheet"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/LineIcons.min.css" rel="stylesheet"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/Glyphter.css" rel="stylesheet"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/jquery-ui.css" rel="stylesheet"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/bootstrap-select.css" rel="stylesheet"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/owl.carousel.min.css" rel="stylesheet"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/styles.css" rel="stylesheet"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/responsive.css" rel="stylesheet"/>
# <meta content="2 BHK Residential Apartment / Flat for sale in New Delhi, Furnished , Affordable, Ready to Move, Freehold, 2 Bedroom Apartment / Flat in New Delhi, 2 Bedroom Property for sale" name="description"/>
# <meta content="2 BHK Residential Apartment / Flat , Apartment / Flat for sale, Apartment / Flat in New Delhi, Fully Furnished Property in New Delhi, 2 Bedroom Property for sale" name="keywords"/>
# <meta content="index, follow" name="robots"/>
# <script async="" crossorigin="anonymous" src="https://connect.facebook.net/en_US/sdk.js?hash=961bf82ba27bb65a070dc87648c5132d&amp;ua=modern_es6"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script id="facebook-jssdk" src="//connect.facebook.net/en_US/sdk.js"></script><script>var metaArray = {AD:"agent-detail/#name#-real-estate-#usertype#-in-#city#/#id#", AL:"agent-search/real-estate-agents-in-#city#", AR:"area/#area#-#category#-property-for-#propertytype#-in-#city#", BD:"residential-search/#bed#bhk-#category#-for-#propertytype#-in-#city#", C:"property-search/#category#-for-#propertytype#-in-#city#", CC:"customer-care", CD:"commercial-detail/#area#-#budget#-#category#-for-#propertytype#-in-#city#/#propertyid#", H:"1", HC:"#city#-property.html", HL:"home-loan", L:"search-property/#category#-for-#propertytype#-in-#city#", LD:"property-detail/#area#-#budget#-#category#-for-#propertytype#-in-#city#/#propertyid#", MA:"myaccount", MP:"map-search/#category#-for-#propertytype#-in-#city#", OD:"owner-detail/#name#/#id#", PP:"privacy-policy", PT:"search/#category#-property-for-#propertytype#-in-#city#", RD:"residential-detail/#area#-#bed#bhk-#category#-for-#propertytype#-in-#city#/#propertyid#", RS:"budget-search/#budget#-#category#-property-for-#propertytype#-in-#city#", TC:"terms-and-conditions"}</script>
# <script>var fbapi = '501366980694192';currentpage="/residential-search/2bhk-residential_apartment_flat-for-sale-in-new_delhi";</script>
# <style>.rbuy, .rrent, .cbuy, .crent, .lbuy{display:none;}.rbuy{display:block;}</style>
# <style data-fbcssmodules="css:fb.css.base css:fb.css.dialog css:fb.css.iframewidget css:fb.css.customer_chat_plugin_iframe" type="text/css">.fb_hidden{position:absolute;top:-10000px;z-index:10001}.fb_reposition{overflow:hidden;position:relative}.fb_invisible{display:none}.fb_reset{background:none;border:0;border-spacing:0;color:#000;cursor:auto;direction:ltr;font-family:"lucida grande", tahoma, verdana, arial, sans-serif;font-size:11px;font-style:normal;font-variant:normal;font-weight:normal;letter-spacing:normal;line-height:1;margin:0;overflow:visible;padding:0;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;visibility:visible;white-space:normal;word-spacing:normal}.fb_reset>div{overflow:hidden}@keyframes fb_transform{from{opacity:0;transform:scale(.95)}to{opacity:1;transform:scale(1)}}.fb_animate{animation:fb_transform .3s forwards}
# .fb_dialog{background:rgba(82, 82, 82, .7);position:absolute;top:-10000px;z-index:10001}.fb_dialog_advanced{border-radius:8px;padding:10px}.fb_dialog_content{background:#fff;color:#373737}.fb_dialog_close_icon{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 0 transparent;cursor:pointer;display:block;height:15px;position:absolute;right:18px;top:17px;width:15px}.fb_dialog_mobile .fb_dialog_close_icon{left:5px;right:auto;top:5px}.fb_dialog_padding{background-color:transparent;position:absolute;width:1px;z-index:-1}.fb_dialog_close_icon:hover{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -15px transparent}.fb_dialog_close_icon:active{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -30px transparent}.fb_dialog_iframe{line-height:0}.fb_dialog_content .dialog_title{background:#6d84b4;border:1px solid #365899;color:#fff;font-size:14px;font-weight:bold;margin:0}.fb_dialog_content .dialog_title>span{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yd/r/Cou7n-nqK52.gif) no-repeat 5px 50%;float:left;padding:5px 0 7px 26px}body.fb_hidden{height:100%;left:0;margin:0;overflow:visible;position:absolute;top:-10000px;transform:none;width:100%}.fb_dialog.fb_dialog_mobile.loading{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/ya/r/3rhSv5V8j3o.gif) white no-repeat 50% 50%;min-height:100%;min-width:100%;overflow:hidden;position:absolute;top:0;z-index:10001}.fb_dialog.fb_dialog_mobile.loading.centered{background:none;height:auto;min-height:initial;min-width:initial;width:auto}.fb_dialog.fb_dialog_mobile.loading.centered #fb_dialog_loader_spinner{width:100%}.fb_dialog.fb_dialog_mobile.loading.centered .fb_dialog_content{background:none}.loading.centered #fb_dialog_loader_close{clear:both;color:#fff;display:block;font-size:18px;padding-top:20px}#fb-root #fb_dialog_ipad_overlay{background:rgba(0, 0, 0, .4);bottom:0;left:0;min-height:100%;position:absolute;right:0;top:0;width:100%;z-index:10000}#fb-root #fb_dialog_ipad_overlay.hidden{display:none}.fb_dialog.fb_dialog_mobile.loading iframe{visibility:hidden}.fb_dialog_mobile .fb_dialog_iframe{position:sticky;top:0}.fb_dialog_content .dialog_header{background:linear-gradient(from(#738aba), to(#2c4987));border-bottom:1px solid;border-color:#043b87;box-shadow:white 0 1px 1px -1px inset;color:#fff;font:bold 14px Helvetica, sans-serif;text-overflow:ellipsis;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0;vertical-align:middle;white-space:nowrap}.fb_dialog_content .dialog_header table{height:43px;width:100%}.fb_dialog_content .dialog_header td.header_left{font-size:12px;padding-left:5px;vertical-align:middle;width:60px}.fb_dialog_content .dialog_header td.header_right{font-size:12px;padding-right:5px;vertical-align:middle;width:60px}.fb_dialog_content .touchable_button{background:linear-gradient(from(#4267B2), to(#2a4887));background-clip:padding-box;border:1px solid #29487d;border-radius:3px;display:inline-block;line-height:18px;margin-top:3px;max-width:85px;padding:4px 12px;position:relative}.fb_dialog_content .dialog_header .touchable_button input{background:none;border:none;color:#fff;font:bold 12px Helvetica, sans-serif;margin:2px -12px;padding:2px 6px 3px 6px;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0}.fb_dialog_content .dialog_header .header_center{color:#fff;font-size:16px;font-weight:bold;line-height:18px;text-align:center;vertical-align:middle}.fb_dialog_content .dialog_content{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/y9/r/jKEcVPZFk-2.gif) no-repeat 50% 50%;border:1px solid #4a4a4a;border-bottom:0;border-top:0;height:150px}.fb_dialog_content .dialog_footer{background:#f5f6f7;border:1px solid #4a4a4a;border-top-color:#ccc;height:40px}#fb_dialog_loader_close{float:left}.fb_dialog.fb_dialog_mobile .fb_dialog_close_icon{visibility:hidden}#fb_dialog_loader_spinner{animation:rotateSpinner 1.2s linear infinite;background-color:transpar ...
# .fb_iframe_widget{display:inline-block;position:relative}.fb_iframe_widget span{display:inline-block;position:relative;text-align:justify}.fb_iframe_widget iframe{position:absolute}.fb_iframe_widget_fluid_desktop,.fb_iframe_widget_fluid_desktop span,.fb_iframe_widget_fluid_desktop iframe{max-width:100%}.fb_iframe_widget_fluid_desktop iframe{min-width:220px;position:relative}.fb_iframe_widget_lift{z-index:1}.fb_iframe_widget_fluid{display:inline}.fb_iframe_widget_fluid span{width:100%}
# .fb_mpn_mobile_landing_page_slide_out{animation-duration:200ms;animation-name:fb_mpn_landing_page_slide_out;transition-timing-function:ease-in}.fb_mpn_mobile_landing_page_slide_out_from_left{animation-duration:200ms;animation-name:fb_mpn_landing_page_slide_out_from_left;transition-timing-function:ease-in}.fb_mpn_mobile_landing_page_slide_up{animation-duration:500ms;animation-name:fb_mpn_landing_page_slide_up;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_in{animation-duration:300ms;animation-name:fb_mpn_bounce_in;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_out{animation-duration:300ms;animation-name:fb_mpn_bounce_out;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_out_v2{animation-duration:300ms;animation-name:fb_mpn_fade_out;transition-timing-function:ease-in}.fb_customer_chat_bounce_in_v2{animation-duration:300ms;animation-name:fb_bounce_in_v2;transition-timing-function:ease-in}.fb_customer_chat_bounce_in_from_left{animation-duration:300ms;animation-name:fb_bounce_in_from_left;transition-timing-function:ease-in}.fb_customer_chat_bounce_out_v2{animation-duration:300ms;animation-name:fb_bounce_out_v2;transition-timing-function:ease-in}.fb_customer_chat_bounce_out_from_left{animation-duration:300ms;animation-name:fb_bounce_out_from_left;transition-timing-function:ease-in}.fb_customer_chat_bubble_animated_no_badge{box-shadow:0 3px 12px rgba(0, 0, 0, .15);transition:box-shadow 150ms linear}.fb_customer_chat_bubble_animated_no_badge:hover{box-shadow:0 5px 24px rgba(0, 0, 0, .3)}.fb_customer_chat_bubble_animated_with_badge{box-shadow:-5px 4px 14px rgba(0, 0, 0, .15);transition:box-shadow 150ms linear}.fb_customer_chat_bubble_animated_with_badge:hover{box-shadow:-5px 8px 24px rgba(0, 0, 0, .2)}.fb_invisible_flow{display:inherit;height:0;overflow-x:hidden;width:0}.fb_new_ui_mobile_overlay_active{overflow:hidden}@keyframes fb_mpn_landing_page_slide_in{0%{border-radius:50%;margin:0 24px;width:60px}40%{border-radius:18px}100%{margin:0 12px;width:100% - 24px}}@keyframes fb_mpn_landing_page_slide_in_from_left{0%{border-radius:50%;left:12px;margin:0 24px;width:60px}40%{border-radius:18px}100%{left:12px;margin:0 12px;width:100% - 24px}}@keyframes fb_mpn_landing_page_slide_out{0%{margin:0 12px;width:100% - 24px}60%{border-radius:18px}100%{border-radius:50%;margin:0 24px;width:60px}}@keyframes fb_mpn_landing_page_slide_out_from_left{0%{left:12px;width:100% - 24px}60%{border-radius:18px}100%{border-radius:50%;left:12px;width:60px}}@keyframes fb_mpn_landing_page_slide_up{0%{bottom:0;opacity:0}100%{bottom:24px;opacity:1}}@keyframes fb_mpn_bounce_in{0%{opacity:.5;top:100%}100%{opacity:1;top:0}}@keyframes fb_mpn_fade_out{0%{bottom:30px;opacity:1}100%{bottom:0;opacity:0}}@keyframes fb_mpn_bounce_out{0%{opacity:1;top:0}100%{opacity:.5;top:100%}}@keyframes fb_bounce_in_v2{0%{opacity:0;transform:scale(0, 0);transform-origin:bottom right}50%{transform:scale(1.03, 1.03);transform-origin:bottom right}100%{opacity:1;transform:scale(1, 1);transform-origin:bottom right}}@keyframes fb_bounce_in_from_left{0%{opacity:0;transform:scale(0, 0);transform-origin:bottom left}50%{transform:scale(1.03, 1.03);transform-origin:bottom left}100%{opacity:1;transform:scale(1, 1);transform-origin:bottom left}}@keyframes fb_bounce_out_v2{0%{opacity:1;transform:scale(1, 1);transform-origin:bottom right}100%{opacity:0;transform:scale(0, 0);transform-origin:bottom right}}@keyframes fb_bounce_out_from_left{0%{opacity:1;transform:scale(1, 1);transform-origin:bottom left}100%{opacity:0;transform:scale(0, 0);transform-origin:bottom left}}@keyframes fb_bounce_out_v2_mobile_chat_started{0%{opacity:1;top:0}100%{opacity:0;top:20px}}@keyframes fb_customer_chat_bubble_bounce_in_animation{0%{bottom:6pt;opacity:0;transform:scale(0, 0);transform-origin:center}70%{bottom:18pt;opacity:1;transform:scale(1.2, 1.2)}100%{transform:scale(1, 1)}}@keyframes slideInFromBottom{0%{opacity:.1;transform:translateY(100%)}100%{opacity:1;transform:translateY(0)}}@keyframes sli ...
# <body class="bodywhite" data-offset="120" data-spy="scroll" data-target=".navbar">
# <header class="fixed-top">
# <div>
# <nav class="navbar navbar-expand-lg navbar-light">
# <a class="navbar-brand" href="https://www.propertiesguru.com/"><img alt="Properties Guru" src="https://www.propertiesguru.com/skin/pg/images/properties-guru-inner-logo.png"/></a>
# <input id="cityid" name="cityid" type="hidden" value="1081"/>
# <input id="cityname" name="cityname" type="hidden" value="New Delhi"/>
# <input id="locationname" name="locationname" type="hidden" value=""/>
# <input id="viewtype" name="viewtype" type="hidden" value="list"/>
# <div class="search-type">
# <div class="select-box">
# <select class="form-control wide" id="popertytype" name="popertytype" style="display: none;">
# <option selected="selected" value="sell">Buy</option>
# <option value="rent">Rent</option>
# </select><div class="nice-select form-control wide" tabindex="0"><span class="current">Buy</span><ul class="list"><li class="option selected" data-value="sell">Buy</li><li class="option" data-value="rent">Rent</li></ul></div>
# </div>
# </div>
# <div class="multi-search">
# <span class="selecteditem"><span class="lc" rel="">New Delhi <i class="fa fa-close"></i></span></span>
# <input class="form-control" id="citylocation" name="citylocation" type="text" value=""/>
# <input id="cityhtml" name="cityhtml" type="hidden" value="new_delhi"/>
# <input id="cathtml" name="cathtml" type="hidden" value="residential_apartment_flat"/>
# <button class="multi-search-btn"><span class="lnr lnr-magnifier"></span></button>
# </div>
# <div class="mobile-panel">
# <ul class="mobile-menu">
# <li><a class="nav-link" href="https://www.propertiesguru.com/listing">List Property</a></li>
# <li class="mobile-user-loged"><a class="nav-link loginmodel" href="javascript:void(0)"><img alt="login my account" class="user-img" height="30" src="https://www.propertiesguru.com/skin/pg/images/agent-img.jpg" width="30"/></a></li>
# </ul>
# </div>
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <!--<div class="my-2 my-lg-0">Chennai</div>-->
# <ul class="navbar-nav ml-md-auto">
# <li class="nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" role="button">Buy</a>
# <div class="dropdown-menu dropdown-menu-right">
# <div class="row">
# <div class="col-md-4">
# <h4><span class="reffidtxt">Residential Property</span></h4>
# <div class="dropdown-divider"></div>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_apartment_flat-for-sale-in-new_delhi">Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_studio_apartment-for-sale-in-new_delhi">Studio Apartment in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_service_apartment-for-sale-in-new_delhi">Service Apartment in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_penthouse-for-sale-in-new_delhi">Penthouse in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_villa_house-for-sale-in-new_delhi">Villa / House in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_builder_floor-for-sale-in-new_delhi">Builder Floor in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_independent_floor-for-sale-in-new_delhi">Independent Floor in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_farm_house-for-sale-in-new_delhi">Farm House in New Delhi</a>
# </div>
# <div class="col-md-4">
# <h4>Residential in New Delhi</h4>
# <div class="dropdown-divider"></div>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/1bhk-residential-for-sale-in-new_delhi">											 Buy 1 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/2bhk-residential-for-sale-in-new_delhi">											 Buy 2 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/3bhk-residential-for-sale-in-new_delhi">											 Buy 3 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/4bhk-residential-for-sale-in-new_delhi">											 Buy 4 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/5bhk-residential-for-sale-in-new_delhi">											 Buy 5 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/6bhk-residential-for-sale-in-new_delhi">											 Buy 6 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/7bhk-residential-for-sale-in-new_delhi">											 Buy 7 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/8bhk-residential-for-sale-in-new_delhi">											 Buy 8 BHK Apartment / Flat in New Delhi</a>
# </div>
# <div class="col-md-4">
# <h4>Nearby Localities</h4>
# <div class="dropdown-divider"></div>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-sale-in-surya_enclave_new_delhi">Apartment / Flat in Surya Enclave</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-sale-in-university_of_delhi_north_campus_new_delhi">Apartment / Flat in University of Delhi North...</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-sale-in-ramakrishna_puram_new_delhi">Apartment / Flat in Ramakrishna Puram</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-sale-in-shakurbasti_new_delhi">Apartment / Flat in Shakurbasti</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-sale-in-janta_colony_new_delhi">Apartment / Flat in Janta Colony</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-sale-in-indira_nagar_new_delhi">Apartment / Flat in Indira Nagar</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-sale-in-khera_khurd_new_delhi">Apartment / Flat in Khera Khurd</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-sale-in-mehrauli_badarpur_road_new_delhi">Apartment / Flat in Mehrauli Badarpur Road</a>
# </div>
# </div>
# </div>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" role="button">Rent
# 							</a>
# <div class="dropdown-menu dropdown-menu-right">
# <div class="row">
# <div class="col-md-4">
# <h4><span class="reffidtxt">Residential</span> Property</h4>
# <div class="dropdown-divider"></div>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_apartment_flat-for-rent-in-new_delhi">Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_studio_apartment-for-rent-in-new_delhi">Studio Apartment in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_service_apartment-for-rent-in-new_delhi">Service Apartment in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_penthouse-for-rent-in-new_delhi">Penthouse in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_villa_house-for-rent-in-new_delhi">Villa / House in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_builder_floor-for-rent-in-new_delhi">Builder Floor in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_independent_floor-for-rent-in-new_delhi">Independent Floor in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_farm_house-for-rent-in-new_delhi">Farm House in New Delhi</a>
# </div>
# <div class="col-md-4">
# <h4>Residential in New Delhi</h4>
# <div class="dropdown-divider"></div>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/1bhk-residential-for-rent-in-new_delhi">Rent 1 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/2bhk-residential-for-rent-in-new_delhi">Rent 2 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/3bhk-residential-for-rent-in-new_delhi">Rent 3 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/4bhk-residential-for-rent-in-new_delhi">Rent 4 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/5bhk-residential-for-rent-in-new_delhi">Rent 5 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/6bhk-residential-for-rent-in-new_delhi">Rent 6 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/7bhk-residential-for-rent-in-new_delhi">Rent 7 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/8bhk-residential-for-rent-in-new_delhi">Rent 8 BHK Apartment / Flat in New Delhi</a>
# </div>
# <div class="col-md-4">
# <h4>Nearby Localities</h4>
# <div class="dropdown-divider"></div>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-rent-in-surya_enclave_new_delhi">Apartment / Flat in Surya Enclave</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-rent-in-university_of_delhi_north_campus_new_delhi">Apartment / Flat in University of Delhi North...</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-rent-in-ramakrishna_puram_new_delhi">Apartment / Flat in Ramakrishna Puram</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-rent-in-shakurbasti_new_delhi">Apartment / Flat in Shakurbasti</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-rent-in-janta_colony_new_delhi">Apartment / Flat in Janta Colony</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-rent-in-indira_nagar_new_delhi">Apartment / Flat in Indira Nagar</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-rent-in-khera_khurd_new_delhi">Apartment / Flat in Khera Khurd</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-rent-in-mehrauli_badarpur_road_new_delhi">Apartment / Flat in Mehrauli Badarpur Road</a>
# </div>
# </div>
# </div>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://www.propertiesguru.com/listing">List Property</a>
# </li>
# <li class="nav-item"><a class="nav-link loginmodel" href="javascript:void(0)"><i aria-hidden="true" class="fa fa-user-o"></i> Login</a></li>
# </ul>
# </div>
# </nav>
# </div>
# </header>
# <div id="mobileheader">
# <div class="container-fluid searchheader header">
# <a href="#"><i class="las la-bars"></i></a>
# <center class="inline">
# <a href="https://www.propertiesguru.com/"><img alt="propertiesguru " class="logo" src="https://www.propertiesguru.com/media/images/mobile-logo2.png"/></a>
# </center>
# <a class="f-right n-decoration list" href="https://www.propertiesguru.com/listing"> List Property <span>FREE</span></a>
# <a href="javascript:void(0);" id="mobilesearchfilters"><i class="search las la-search"></i></a>
# </div>
# </div>
# <nav class="navbar navbar-expand-md navbar-light pg-filter headbar">
# <button aria-controls="navbarNavDropdown" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarNavDropdown" data-toggle="collapse" type="button">Advance Search</button>
# <div class="collapse navbar-collapse" id="navbarNavDropdown">
# <a class="navbar-brand" href="#"><img alt="propertiesguru.com" src="https://www.propertiesguru.com/skin/pg/images/filter-nav-icon.png"/></a>
# <ul class="navbar-nav mr-md-no">
# <li class="nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle cat" data-toggle="dropdown" href="#" id="navbarDropdownMenuLink"><i class="fa fa-check-circle show"></i>Property Type</a>
# <ul aria-labelledby="navbarDropdownMenuLink" class="dropdown-menu form-content category">
# <li>
# <a catid="1" class="dropdown-item dropdown-toggle catreffid1" href="#" html="residential" onclick="$('#cathtml').val('residential');" rel="catreffid1">Residential Property</a>
# <ul class="dropdown-menu show catreffid1">
# <li>
# <div class="negotiable">
# <div class="red-check checkallcat">
# <input class="checkall" id="catid1" name="checkall" type="checkbox" value="-1"/>
# <label for="catid1">All Residential</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input checked="checked" class="catid1" id="reffid3" name="catid[]" rel="1" type="checkbox" value="3,28,29,30"/>
# <label for="reffid3">Apartment / Flat</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid1" id="reffid31" name="catid[]" rel="1" type="checkbox" value="31"/>
# <label for="reffid31">Villa / House</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid1" id="reffid32" name="catid[]" rel="1" type="checkbox" value="32,33"/>
# <label for="reffid32">Builder Floor</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid1" id="reffid35" name="catid[]" rel="1" type="checkbox" value="35"/>
# <label for="reffid35">Farm House</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <a catid="2" class="dropdown-item dropdown-toggle catreffid2" href="#" html="commercial" onclick="$('#cathtml').val('commercial');" rel="catreffid2">Commercial Property</a>
# <ul class="dropdown-menu catreffid2">
# <li>
# <div class="negotiable">
# <div class="red-check checkallcat">
# <input class="checkall" id="catid2" name="checkall" type="checkbox" value="-1"/>
# <label for="catid2">All Commercial</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid2" id="reffid18" name="catid[]" rel="2" type="checkbox" value="18"/>
# <label for="reffid18">Office Space</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid2" id="reffid19" name="catid[]" rel="2" type="checkbox" value="19"/>
# <label for="reffid19">Shop</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid2" id="reffid20" name="catid[]" rel="2" type="checkbox" value="20"/>
# <label for="reffid20">Showroom</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid2" id="reffid21" name="catid[]" rel="2" type="checkbox" value="21"/>
# <label for="reffid21">Retail Space</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <a catid="4" class="dropdown-item dropdown-toggle catreffid4" href="#" html="landplot" onclick="$('#cathtml').val('landplot');" rel="catreffid4">Land / Plot Property</a>
# <ul class="dropdown-menu catreffid4">
# <li>
# <div class="negotiable">
# <div class="red-check checkallcat">
# <input class="checkall" id="catid4" name="checkall" type="checkbox" value="-1"/>
# <label for="catid4">All Land / Plot</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid4" id="reffid24" name="catid[]" rel="4" type="checkbox" value="24"/>
# <label for="reffid24">Residential Plot</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid4" id="reffid25" name="catid[]" rel="4" type="checkbox" value="25"/>
# <label for="reffid25">Agriculture Land</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid4" id="reffid26" name="catid[]" rel="4" type="checkbox" value="26"/>
# <label for="reffid26">Commercial Plot</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid4" id="reffid27" name="catid[]" rel="4" type="checkbox" value="27"/>
# <label for="reffid27">Industrial Land</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# </ul>
# </li>
# </ul>
# <input id="reffid" name="reffid" type="hidden" value="1"/>
# </li>
# <li class="nav-item dropdown budgetnav">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle bugt" data-toggle="dropdown" href="#" id="navbarDropdownMenuLink"><i class="fa fa-check-circle"></i>Budget</a>
# <ul aria-labelledby="navbarDropdownMenuLink" class="dropdown-menu form-content">
# <li>
# <div class="row no-gutters form-content budget totalbudget">
# <div class="col-6">
# <input class="form-control" id="minbudget" name="minbudget" placeholder="Min" type="text" value=""/>
# </div>
# <div class="col-6">
# <input class="form-control" id="maxbudget" name="maxbudget" placeholder="Max" type="text" value=""/>
# </div>
# </div>
# <div class="row no-gutters form-content budget scroll budget totalbudget">
# <div class="col-6 budgetsell">
# <ul class="min">
# <li><a href="#" rel="0">Min</a></li>
# <li><a class="" href="#" rel="1500000"><span>₹</span>15 Lac</a></li>
# <li><a class="" href="#" rel="2500000"><span>₹</span>25 Lac</a></li>
# <li><a class="" href="#" rel="5000000"><span>₹</span>50 Lac</a></li>
# <li><a class="" href="#" rel="10000000"><span>₹</span>1 Cr</a></li>
# <li><a class="" href="#" rel="15000000"><span>₹</span>1.5 Cr</a></li>
# <li><a class="" href="#" rel="25000000"><span>₹</span>2.5 Cr</a></li>
# <li><a class="" href="#" rel="30000000"><span>₹</span>3 Cr</a></li>
# <li><a class="" href="#" rel="40000000"><span>₹</span>4 Cr</a></li>
# <li><a class="" href="#" rel="50000000"><span>₹</span>5 Cr</a></li>
# <li><a class="" href="#" rel="70000000"><span>₹</span>7 Cr</a></li>
# <li><a class="" href="#" rel="100000000"><span>₹</span>10 Cr</a></li>
# <li><a class="" href="#" rel="200000000"><span>₹</span>20 Cr</a></li>
# </ul>
# </div>
# <div class="col-6 budgetsell">
# <ul class="max">
# <li><a class="" href="#" rel="1500000"><span>₹</span>15 Lac</a></li>
# <li><a class="" href="#" rel="2500000"><span>₹</span>25 Lac</a></li>
# <li><a class="" href="#" rel="5000000"><span>₹</span>50 Lac</a></li>
# <li><a class="" href="#" rel="10000000"><span>₹</span>1 Cr</a></li>
# <li><a class="" href="#" rel="15000000"><span>₹</span>1.5 Cr</a></li>
# <li><a class="" href="#" rel="25000000"><span>₹</span>2.5 Cr</a></li>
# <li><a class="" href="#" rel="30000000"><span>₹</span>3 Cr</a></li>
# <li><a class="" href="#" rel="40000000"><span>₹</span>4 Cr</a></li>
# <li><a class="" href="#" rel="50000000"><span>₹</span>5 Cr</a></li>
# <li><a class="" href="#" rel="70000000"><span>₹</span>7 Cr</a></li>
# <li><a class="" href="#" rel="100000000"><span>₹</span>10 Cr</a></li>
# <li><a class="" href="#" rel="200000000"><span>₹</span>20 Cr</a></li>
# <li><a href="#" rel=""><span>₹</span>Max</a></li>
# </ul>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li class="nav-item dropdown bedroomdropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle bd" data-toggle="dropdown" href="#" id="navbarDropdownMenuLink"><i class="fa fa-check-circle show"></i>BHK</a>
# <ul aria-labelledby="navbarDropdownMenuLink" class="dropdown-menu form-content dropdown-beds">
# <li>
# <div class="row no-gutters form-content navbads">
# <ul class="property-type room-no pull-right">
# <li>
# <input class="bedroom" id="1" name="rooms-no" type="checkbox" value="1"/>
# <label for="1"><span>1</span></label>
# <div class="check"></div>
# </li>
# <li>
# <input checked="" class="bedroom" id="2" name="rooms-no" type="checkbox" value="2"/>
# <label for="2"><span>2</span></label>
# <div class="check"></div>
# </li>
# <li>
# <input class="bedroom" id="3" name="rooms-no" type="checkbox" value="3"/>
# <label for="3"><span>3</span></label>
# <div class="check"></div>
# </li>
# <li>
# <input class="bedroom" id="4" name="rooms-no" type="checkbox" value="4"/>
# <label for="4"><span>4</span></label>
# <div class="check"></div>
# </li>
# <li>
# <div class="select-box select-text room-box resetdrop">
# <select class="form-control rooom-no wide bedroom" id="select_bed" name="select_bed" style="display: none;">
# <option value="">4+</option>
# <option value="5">5</option>
# <option value="6">6</option>
# <option value="7">7</option>
# <option value="8">8</option>
# <option value="9">9</option>
# <option value="10">10</option>
# </select><div class="nice-select form-control rooom-no wide bedroom" tabindex="0"><span class="current">4+</span><ul class="list"><li class="option selected" data-value="">4+</li><li class="option" data-value="5">5</li><li class="option" data-value="6">6</li><li class="option" data-value="7">7</li><li class="option" data-value="8">8</li><li class="option" data-value="9">9</li><li class="option" data-value="10">10</li></ul></div>
# </div>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# </li>
# <li class="nav-item dropdown areanav">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle ar" data-toggle="dropdown" href="#" id="navbarDropdownMenuLink"><i class="fa fa-check-circle"></i>Area
#
# 				</a>
# <ul aria-labelledby="navbarDropdownMenuLink" class="dropdown-menu form-content">
# <li>
# <div class="row no-gutters form-content budget totalarea">
# <div class="col-6">
# <input class="form-control" id="minarea" name="minarea" placeholder="Min" type="text" value=""/>
# </div>
# <div class="col-6">
# <input class="form-control" id="maxarea" name="maxarea" placeholder="Max" type="text" value=""/>
# </div>
# </div>
# <div class="row no-gutters form-content budget totalarea">
# <div class="col-8 offset-2">
# <div class="select-box resetdrop">
# <select class="form-control wide" id="areatype" name="areatype" style="display: none;">
# <option rel="1" value="Sq Ft.">Sq Ft.</option>
# <option rel="9" value="Sq Yd.">Sq Yd.</option>
# <option rel="10.7639" value="Sq Mtr">Sq Mtr</option>
# <option rel="107639" value="Hectares">Hectares</option>
# <option rel="43560" value="Acres">Acres</option>
# </select><div class="nice-select form-control wide" tabindex="0"><span class="current">Sq Ft.</span><ul class="list"><li class="option selected" data-value="Sq Ft.">Sq Ft.</li><li class="option" data-value="Sq Yd.">Sq Yd.</li><li class="option" data-value="Sq Mtr">Sq Mtr</li><li class="option" data-value="Hectares">Hectares</li><li class="option" data-value="Acres">Acres</li></ul></div>
# </div>
# </div>
# </div>
# <div class="row no-gutters form-content budget scroll totalarea">
# <div class="col-6">
# <ul class="min">
# <li><a class="" href="#" rel="0">Min</a></li>
# <li><a class="" href="#" rel="100">100</a></li>
# <li><a class="" href="#" rel="200">200</a></li>
# <li><a class="" href="#" rel="300">300</a></li>
# <li><a class="" href="#" rel="500">500</a></li>
# <li><a class="" href="#" rel="1000">1000</a></li>
# <li><a class="" href="#" rel="1500">1500</a></li>
# <li><a class="" href="#" rel="2000">2000</a></li>
# <li><a class="" href="#" rel="2500">2500</a></li>
# <li><a class="" href="#" rel="3000">3000</a></li>
# <li><a class="" href="#" rel="4000">4000</a></li>
# <li><a class="" href="#" rel="5000">5000</a></li>
# <li><a class="" href="#" rel="6000">6000</a></li>
# <li><a class="" href="#" rel="7000">7000</a></li>
# <li><a class="" href="#" rel="8000">8000</a></li>
# <li><a class="" href="#" rel="9000">9000</a></li>
# </ul>
# </div>
# <div class="col-6">
# <ul class="max">
# <li><a class="" href="#" rel="100">100</a></li>
# <li><a class="" href="#" rel="200">200</a></li>
# <li><a class="" href="#" rel="300">300</a></li>
# <li><a class="" href="#" rel="500">500</a></li>
# <li><a class="" href="#" rel="1000">1000</a></li>
# <li><a class="" href="#" rel="1500">1500</a></li>
# <li><a class="" href="#" rel="2000">2000</a></li>
# <li><a class="" href="#" rel="2500">2500</a></li>
# <li><a class="" href="#" rel="3000">3000</a></li>
# <li><a class="" href="#" rel="4000">4000</a></li>
# <li><a class="" href="#" rel="5000">5000</a></li>
# <li><a class="" href="#" rel="6000">6000</a></li>
# <li><a class="" href="#" rel="7000">7000</a></li>
# <li><a class="" href="#" rel="8000">8000</a></li>
# <li><a class="" href="#" rel="9000">9000</a></li>
# <li><a class="" href="#" rel="">Max</a></li>
# </ul>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle oh" data-toggle="dropdown" href="#" id="navbarDropdownMenuLink"><i class="fa fa-check-circle"></i>More
#
# 							<i aria-hidden="true" class="fa fa-sliders"></i>
# </a>
# <ul aria-labelledby="navbarDropdownMenuLink" class="dropdown-menu navdropmore form-content">
# <li>
# <div class="row form-content budget navmore">
# <div class="col-12">
# <div class="negotiable">
# <div class="red-check">
# <input id="PropertiesPhotos" name="PropertiesPhotos" type="checkbox" value="Show Properties with Photos only"/>
# <label for="PropertiesPhotos">Show Properties with Photos only</label>
# <div class="check"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="
a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-vadodara">Buy Property in Vadodara</a></li>
# </ul>
# </div>
# <div>
# <h4>Connect With Us</h4>
# <ul>
# <li>Need any help? Write to us at:</li>
# <li><i class="fa fa-envelope-o"></i><a href="mailto:support@propertiesguru.com">support@propertiesguru.com</a></li>
# <div class="social-icons">
# <a class="fa fa-twitter" href="https://twitter.com/propertiesguru2" target="_blank"></a>
# <a class="fa fa-linkedin" href="https://www.linkedin.com/groups/13793163/" target="_blank"></a>
# <a class="fa fa-facebook" href="https://www.facebook.com/propertiesguruindia/" target="_blank"></a>
# </div>
# </ul>
# </div>
# </div>
# <div class="footer-bottom">
# <span>All Rights Reserved. © Copyright 2021 PropertiesGuru.com. <a href="https://www.propertiesguru.com/privacy-policy">Privacy Policy</a> | <a href="https://www.propertiesguru.com/terms-and-conditions">Terms and Conditions</a></span>
# </div>
# <div class="footer-bottom">
# <span><strong>Disclaimer: </strong>Propertiesguru.com (Website owned by: Aashi E-Net Solutions Pvt. Ltd.) is online real estate platform facilitate the property owners / buyers / agents / builders to exchange the general information of real estate project / property details, property types, floor area, location, Map and images etc. The details, so published here been sourced out from multiple sources on “as is” and “as available” on best effort basis. It should not deemed to constitute advertisement, solicitation, invitation to offer, offers to sale by any Property Developer/ Builder/ Agent or any other entity. For more info <a href="https://www.propertiesguru.com/terms-and-conditions#disclaimer">Click here</a>. <!--Propertiesguru.com is not marketing, sales partner or entity of any real estate projects / developer / agents. There is possibility that the property information being provided by the seller / developer may not be complete or correct due to update on regular interval basis. So you are requested to ensure the authenticity and verify / validate the accuracy of a property details from the respective Seller / Builders / Agents. Same can also be checked on RERA website for the respective property project / developer / agents before buying / renting the property. PropertiesGuru.com and its Directors, Employees, Associates neither responsible nor liable for any accuracy for the personal or property information and for action taken cases, cost, expenses incurred by any entity person based on the information given on our website. We reserve the right to add, modify, delete and revoke any information without any notification. So by using our website you agree the disclaimer without any limitation and are solely responsible for any risk or consequences without any recourse to PropertiesGuru.com--></span>
# </div>
# </div>
# </footer>
# <a class="back-to-top" href="javascript:void" id="back-to-top" role="button" style="display: inline;"><i aria-hidden="true" class="fa fa-angle-double-up"></i></a>
# <div class="modal login-signup-modal fade" id="login-signup-modal">
# <div class="modal-dialog modal-md">
# <div class="modal-content">
# </div>
# </div>
# </div>
# <div class="modal contact-modal fade" id="contact-modal">
# <div class="modal-dialog">
# <div class="modal-content">
# <button class="close" data-dismiss="modal" type="button">×</button>
# <div class="modal-body">
# </div>
# </div>
# </div>
# </div>
# <div class="modal alert-modal fade" id="setalert"><div class="modal-dialog"><div class="modal-content"><button class="close" data-dismiss="modal" type="button">×</button><div class="modal-body"></div></div></div></div>
# <script src="https://www.propertiesguru.com/skin/pg/js/jquery-3.2.1.min.js"></script>
# <script src="https://www.propertiesguru.com/skin/pg/js/jquery-ui.js"></script>
# <script src="https://www.propertiesguru.com/skin/pg/js/bootstrap.min.js"></script>
# <script src="https://www.propertiesguru.com/skin/pg/js/bootstrap-select.js"></script>
# <script src="https://www.propertiesguru.com/skin/pg/js/jquery.navScroll.min.js"></script>
# <script src="https://www.propertiesguru.com/skin/pg/js/owl.carousel.min.js"></script>
# <script src="https://www.propertiesguru.com/skin/pg/js/jquery.mCustomScrollbar.concat.min.js"></script>
# <span class="reloadjs"><script src="https://www.propertiesguru.com/skin/pg/js/custom.js"></script></span>
# <script>var basepath = "https://www.propertiesguru.com/", pg="search",steps="";</script>
# <script src="https://www.propertiesguru.com/media/js/login.js"></script>
# <script src="https://www.propertiesguru.com/media/js/mobilesearch.js" type="text/javascript"></script>
# <script>
#
# $(document).on("click",".detailurl",function(){
# 	var lnk = $(this).attr("detailurl");
# 	if(lnk!=""){
# 		if($(window).width() <= 1024) window.location.href=lnk;
# 		else window.open(lnk,'_blank');
# 	}
#
# });
#
# $(document).on("click",".detailurl a",function(e){e.stopPropagation();});
#
# $(document).on('click.bs.dropdown.data-api', '.nav-item.dropdown', function (e) {e.stopPropagation();});
#
# $(document).on("click",".favourite",function(){
#
# 	var obj = $(this);
#
# 	$.ajax({
#
# 		url : "https://www.propertiesguru.com/detail/favourite/" + obj.attr("type")+"/" + obj.attr("rel"),
#
# 		success:function(data){
#
# 			if(data == 0) obj.removeClass("active");
#
# 			else obj.addClass("active");
#
# 		}
#
# 	});
#
# });
#
# $(".footer-menu-block h4").click(function(){
#
# 	//$(".footer-menu-block ul").hide("slow");
#
# 	$(this).closest("div").find("ul").slideToggle('slow');
#
# });
#
# </script>
# <script src="https://www.propertiesguru.com/media/js/jquery.autocomplete.min.js" type="text/javascript"></script>
# <script src="https://www.propertiesguru.com/media/js/popup.js" type="text/javascript"></script><script>
# 			/*$(".getpropertypopup").click(function(){
# 				$.ajax({
# 					url:"https://www.propertiesguru.com/detail/contactus/getpopup?type=property&name=&usertype=&phone=&agentid=&imagename=&propertyid=&reffid=&propertytype=&propertyinfo",
# 					success:function(data){
# 						$("#contact-modal .modal-body").html(data);
# 					}
# 				});
# 			});*/
# 			$('.js-example-basic-single').select2();var rowperpage = 10;</script>
# <script src="https://www.propertiesguru.com/media/js/search.js" type="text/javascript"></script>
# <script async="" defer="" src="https://maps.googleapis.com/maps/api/js?v=3.exp&amp;sensor=false&amp;key=AIzaSyCOZXFhy15WLmP465brkwxZbquO58PMNTY&amp;callback=initMap"></script>
# <div class="modal mapview-modal fade" id="mapview-modal"><div class="modal-dialog modal-md"><div class="modal-content"></div></div></div>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-148384149-1"></script>
# <script>
#
#   window.dataLayer = window.dataLayer || [];
#
#   function gtag(){dataLayer.push(arguments);}
#
#   gtag('js', new Date());
#
#
#
#   gtag('config', 'UA-148384149-1');
#
# </script>
# <div class="fb_reset" id="fb-root"><div style="position: absolute; top: -10000px; width: 0px; height: 0px;"><div></div></div></div></body></html>

# %%
df = pd.DataFrame()

# %%
for k in soup.find_all("div", class_="filter-property-list detailurl"):
    title=k.find("h1", class_="filter-pro-heading").text.split("  ")[0]
    address=k.find("h1", class_="filter-pro-heading").text.split("  ")[1]
    price=k.find("span", class_="price").text
    image=k.find("img")['src']
    area=k.find("div", class_="col-4").text.replace("Area","")
    facing=k.find("div", class_="col-sm-7").find("div", class_="col-3").text.replace("Facing","")
    status=k.find("div", class_="col-sm-7").find("div", class_="col-5").text.replace("Status","")
    contact_name=k.find("div", class_="contact-details").text.split("\n")[1]
    posted=k.find("div", class_="contact-details").text.split("\n")[2].replace("Posted:  ","")
    
    df2 = {'Title': title, 'Address': address, "Price": price, "Area":area, "Facing":facing, 
          'Status':status, "Contact_Name": contact_name, "Posted": posted, "Image":image}
    df = df.append(df2, ignore_index = True)

# %%
df
# Out:
#                            Address           Area             Contact_Name  \
# 0   GH 13 Paschim Vihar, New Delhi    1200 Sq Ft.           Rohit  (Agent)
# 1         Okhla Phase 1, New Delhi    2234 Sq Ft.  krishna shukla  (Agent)
# 2          Chirag Delhi, New Delhi      80 Sq Yd.      Asha Kadwal (Owner)
#             Posted   Price              Status  \
# 0    6 Months  ago  1.25Cr       Ready to Move
# 1   10 Months  ago  4.81Cr  Under Construction
# 2   10 Months  ago   45Lac       Ready to Move
# 3   10 Months  ago  4.82Cr  Under Construction
# 4   11 Months  ago   1.2Cr       Ready to Move
# 5      1 Year  ago   1.2Cr       Ready to Move
# 6      1 Year  ago   1.6Cr       Ready to Move
# 7      1 Year  ago  1.55Cr       Ready to Move
# 8      1 Year  ago   30Lac       Ready to Move
# 9      1 Year  ago  4.49Cr  Under Construction
# 10     1 Year  ago  1.55Cr       Ready to Move
# 11     1 Year  ago  1.55Cr       Ready to Move
# 12  11 Months  ago  1.55Cr       Ready to Move
# 13     1 Year  ago  1.55Cr       Ready to Move
# 14     1 Year  ago   15Lac       Ready to Move
# 15     1 Year  ago   12Lac       Ready to Move
# 16     1 Year  ago  1.35Cr       Ready to Move
# 17     1 Year  ago  1.15Cr       Ready to Move
# 18     1 Year  ago     4Cr       Ready to Move
# 19     1 Year  ago   85Lac       Ready to Move
# 20     1 Year  ago  1.55Cr       Ready to Move
# 21     1 Year  ago   85Lac       Ready to Move
# 22     1 Year  ago  1.45Cr       Ready to Move
# 23     1 Year  ago   95Lac       Ready to Move
#
#                               Title
# 0   2 BHK Apartment / Flat for Sale
# 1   2 BHK Apartment / Flat for Sale
# 2   2 BHK Apartment / Flat for Sale
# 3   2 BHK Apartment / Flat for Sale
# 4   2 BHK Studio Apartment for Sale
# 5   2 BHK Apartment / Flat for Sale
# 6   2 BHK Apartment / Flat for Sale
# 7   2 BHK Apartment / Flat for Sale
# 8   2 BHK Apartment / Flat for Sale
# 9   2 BHK Apartment / Flat for Sale
# 10  2 BHK Apartment / Flat for Sale
# 11  2 BHK Apartment / Flat for Sale
# 12  2 BHK Apartment / Flat for Sale
# 13  2 BHK Apartment / Flat for Sale
# 14  2 BHK Apartment / Flat for Sale
# 15  2 BHK Apartment / Flat for Sale
# 16  2 BHK Apartment / Flat for Sale
# 17  2 BHK Apartment / Flat for Sale
# 18  2 BHK Apartment / Flat for Sale
# 19  2 BHK Apartment / Flat for Sale
# 20  2 BHK Studio Apartment for Sale
# 21  2 BHK Apartment / Flat for Sale
# 22  2 BHK Apartment / Flat for Sale
# 23  2 BHK Studio Apartment for Sale

# %%
df.to_excel("2BHK_Property_Output.xlsx")

# %% [markdown]
# ### For 3 BHK

# %%
link="https://www.propertiesguru.com/residential-search/2bhk-residential_apartment_flat-for-sale-in-new_delhi"
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import SessionNotCreatedException
from selenium.webdriver.support.ui import Select

driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(link)

bhkbutton=driver.find_element_by_xpath("//a[@id='navbarDropdownMenuLink' and text()='BHK']").click()

checkboxElement = driver.find_element_by_xpath("//input[@id='2']")
driver.execute_script("arguments[0].click();", checkboxElement)

reqcheckboxElement = driver.find_element_by_xpath("//input[@id='3']")
driver.execute_script("arguments[0].click();", reqcheckboxElement)

initial_value=0
next_value=500
#driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
while next_value<30000:
    driver.execute_script("window.scrollTo({},{});".format(initial_value, next_value))
  
    initial_value=next_value
    next_value+=300
# Out:
# [WDM] - Current google-chrome version is 91.0.4472
# [WDM] - Get LATEST driver version for 91.0.4472
# [WDM] - Driver [C:\Users\hp\.wdm\drivers\chromedriver\win32\91.0.4472.101\chromedriver.exe] found in cache

# %%
newhtml = driver.page_source
newsoup = BeautifulSoup(newhtml)
newsoup
# Out:
# <html lang="en-US"><head>
# <meta content="notranslate" name="google"/>
# <link href="https://www.propertiesguru.com/media/images/favicon.png" rel="icon" sizes="16x16" type="image/png"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>2 BHK Apartment / Flat in New Delhi | Residential Apartment / Flat for sale in New Delhi</title>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/icon-font.min.css" rel="stylesheet"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/LineIcons.min.css" rel="stylesheet"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/Glyphter.css" rel="stylesheet"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/jquery-ui.css" rel="stylesheet"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/bootstrap-select.css" rel="stylesheet"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/owl.carousel.min.css" rel="stylesheet"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/styles.css" rel="stylesheet"/>
# <link href="https://www.propertiesguru.com/skin/pg/css/responsive.css" rel="stylesheet"/>
# <meta content="2 BHK Residential Apartment / Flat for sale in New Delhi, Furnished , Affordable, Ready to Move, Freehold, 2 Bedroom Apartment / Flat in New Delhi, 2 Bedroom Property for sale" name="description"/>
# <meta content="2 BHK Residential Apartment / Flat , Apartment / Flat for sale, Apartment / Flat in New Delhi, Fully Furnished Property in New Delhi, 2 Bedroom Property for sale" name="keywords"/>
# <meta content="index, follow" name="robots"/>
# <script async="" crossorigin="anonymous" src="https://connect.facebook.net/en_US/sdk.js?hash=ffc6f971b524a1f8183a328563c9fb15&amp;ua=modern_es6"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script id="facebook-jssdk" src="//connect.facebook.net/en_US/sdk.js"></script><script>var metaArray = {AD:"agent-detail/#name#-real-estate-#usertype#-in-#city#/#id#", AL:"agent-search/real-estate-agents-in-#city#", AR:"area/#area#-#category#-property-for-#propertytype#-in-#city#", BD:"residential-search/#bed#bhk-#category#-for-#propertytype#-in-#city#", C:"property-search/#category#-for-#propertytype#-in-#city#", CC:"customer-care", CD:"commercial-detail/#area#-#budget#-#category#-for-#propertytype#-in-#city#/#propertyid#", H:"1", HC:"#city#-property.html", HL:"home-loan", L:"search-property/#category#-for-#propertytype#-in-#city#", LD:"property-detail/#area#-#budget#-#category#-for-#propertytype#-in-#city#/#propertyid#", MA:"myaccount", MP:"map-search/#category#-for-#propertytype#-in-#city#", OD:"owner-detail/#name#/#id#", PP:"privacy-policy", PT:"search/#category#-property-for-#propertytype#-in-#city#", RD:"residential-detail/#area#-#bed#bhk-#category#-for-#propertytype#-in-#city#/#propertyid#", RS:"budget-search/#budget#-#category#-property-for-#propertytype#-in-#city#", TC:"terms-and-conditions"}</script>
# <script>var fbapi = '501366980694192';currentpage="/residential-search/2bhk-residential_apartment_flat-for-sale-in-new_delhi";</script>
# <style>.rbuy, .rrent, .cbuy, .crent, .lbuy{display:none;}.rbuy{display:block;}</style>
# <style data-fbcssmodules="css:fb.css.base css:fb.css.dialog css:fb.css.iframewidget css:fb.css.customer_chat_plugin_iframe" type="text/css">.fb_hidden{position:absolute;top:-10000px;z-index:10001}.fb_reposition{overflow:hidden;position:relative}.fb_invisible{display:none}.fb_reset{background:none;border:0;border-spacing:0;color:#000;cursor:auto;direction:ltr;font-family:"lucida grande", tahoma, verdana, arial, sans-serif;font-size:11px;font-style:normal;font-variant:normal;font-weight:normal;letter-spacing:normal;line-height:1;margin:0;overflow:visible;padding:0;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;visibility:visible;white-space:normal;word-spacing:normal}.fb_reset>div{overflow:hidden}@keyframes fb_transform{from{opacity:0;transform:scale(.95)}to{opacity:1;transform:scale(1)}}.fb_animate{animation:fb_transform .3s forwards}
# .fb_dialog{background:rgba(82, 82, 82, .7);position:absolute;top:-10000px;z-index:10001}.fb_dialog_advanced{border-radius:8px;padding:10px}.fb_dialog_content{background:#fff;color:#373737}.fb_dialog_close_icon{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 0 transparent;cursor:pointer;display:block;height:15px;position:absolute;right:18px;top:17px;width:15px}.fb_dialog_mobile .fb_dialog_close_icon{left:5px;right:auto;top:5px}.fb_dialog_padding{background-color:transparent;position:absolute;width:1px;z-index:-1}.fb_dialog_close_icon:hover{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -15px transparent}.fb_dialog_close_icon:active{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -30px transparent}.fb_dialog_iframe{line-height:0}.fb_dialog_content .dialog_title{background:#6d84b4;border:1px solid #365899;color:#fff;font-size:14px;font-weight:bold;margin:0}.fb_dialog_content .dialog_title>span{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yd/r/Cou7n-nqK52.gif) no-repeat 5px 50%;float:left;padding:5px 0 7px 26px}body.fb_hidden{height:100%;left:0;margin:0;overflow:visible;position:absolute;top:-10000px;transform:none;width:100%}.fb_dialog.fb_dialog_mobile.loading{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/ya/r/3rhSv5V8j3o.gif) white no-repeat 50% 50%;min-height:100%;min-width:100%;overflow:hidden;position:absolute;top:0;z-index:10001}.fb_dialog.fb_dialog_mobile.loading.centered{background:none;height:auto;min-height:initial;min-width:initial;width:auto}.fb_dialog.fb_dialog_mobile.loading.centered #fb_dialog_loader_spinner{width:100%}.fb_dialog.fb_dialog_mobile.loading.centered .fb_dialog_content{background:none}.loading.centered #fb_dialog_loader_close{clear:both;color:#fff;display:block;font-size:18px;padding-top:20px}#fb-root #fb_dialog_ipad_overlay{background:rgba(0, 0, 0, .4);bottom:0;left:0;min-height:100%;position:absolute;right:0;top:0;width:100%;z-index:10000}#fb-root #fb_dialog_ipad_overlay.hidden{display:none}.fb_dialog.fb_dialog_mobile.loading iframe{visibility:hidden}.fb_dialog_mobile .fb_dialog_iframe{position:sticky;top:0}.fb_dialog_content .dialog_header{background:linear-gradient(from(#738aba), to(#2c4987));border-bottom:1px solid;border-color:#043b87;box-shadow:white 0 1px 1px -1px inset;color:#fff;font:bold 14px Helvetica, sans-serif;text-overflow:ellipsis;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0;vertical-align:middle;white-space:nowrap}.fb_dialog_content .dialog_header table{height:43px;width:100%}.fb_dialog_content .dialog_header td.header_left{font-size:12px;padding-left:5px;vertical-align:middle;width:60px}.fb_dialog_content .dialog_header td.header_right{font-size:12px;padding-right:5px;vertical-align:middle;width:60px}.fb_dialog_content .touchable_button{background:linear-gradient(from(#4267B2), to(#2a4887));background-clip:padding-box;border:1px solid #29487d;border-radius:3px;display:inline-block;line-height:18px;margin-top:3px;max-width:85px;padding:4px 12px;position:relative}.fb_dialog_content .dialog_header .touchable_button input{background:none;border:none;color:#fff;font:bold 12px Helvetica, sans-serif;margin:2px -12px;padding:2px 6px 3px 6px;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0}.fb_dialog_content .dialog_header .header_center{color:#fff;font-size:16px;font-weight:bold;line-height:18px;text-align:center;vertical-align:middle}.fb_dialog_content .dialog_content{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/y9/r/jKEcVPZFk-2.gif) no-repeat 50% 50%;border:1px solid #4a4a4a;border-bottom:0;border-top:0;height:150px}.fb_dialog_content .dialog_footer{background:#f5f6f7;border:1px solid #4a4a4a;border-top-color:#ccc;height:40px}#fb_dialog_loader_close{float:left}.fb_dialog.fb_dialog_mobile .fb_dialog_close_icon{visibility:hidden}#fb_dialog_loader_spinner{animation:rotateSpinner 1.2s linear infinite;background-color:transpar ...
# .fb_iframe_widget{display:inline-block;position:relative}.fb_iframe_widget span{display:inline-block;position:relative;text-align:justify}.fb_iframe_widget iframe{position:absolute}.fb_iframe_widget_fluid_desktop,.fb_iframe_widget_fluid_desktop span,.fb_iframe_widget_fluid_desktop iframe{max-width:100%}.fb_iframe_widget_fluid_desktop iframe{min-width:220px;position:relative}.fb_iframe_widget_lift{z-index:1}.fb_iframe_widget_fluid{display:inline}.fb_iframe_widget_fluid span{width:100%}
# .fb_mpn_mobile_landing_page_slide_out{animation-duration:200ms;animation-name:fb_mpn_landing_page_slide_out;transition-timing-function:ease-in}.fb_mpn_mobile_landing_page_slide_out_from_left{animation-duration:200ms;animation-name:fb_mpn_landing_page_slide_out_from_left;transition-timing-function:ease-in}.fb_mpn_mobile_landing_page_slide_up{animation-duration:500ms;animation-name:fb_mpn_landing_page_slide_up;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_in{animation-duration:300ms;animation-name:fb_mpn_bounce_in;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_out{animation-duration:300ms;animation-name:fb_mpn_bounce_out;transition-timing-function:ease-in}.fb_mpn_mobile_bounce_out_v2{animation-duration:300ms;animation-name:fb_mpn_fade_out;transition-timing-function:ease-in}.fb_customer_chat_bounce_in_v2{animation-duration:300ms;animation-name:fb_bounce_in_v2;transition-timing-function:ease-in}.fb_customer_chat_bounce_in_from_left{animation-duration:300ms;animation-name:fb_bounce_in_from_left;transition-timing-function:ease-in}.fb_customer_chat_bounce_out_v2{animation-duration:300ms;animation-name:fb_bounce_out_v2;transition-timing-function:ease-in}.fb_customer_chat_bounce_out_from_left{animation-duration:300ms;animation-name:fb_bounce_out_from_left;transition-timing-function:ease-in}.fb_customer_chat_bubble_animated_no_badge{box-shadow:0 3px 12px rgba(0, 0, 0, .15);transition:box-shadow 150ms linear}.fb_customer_chat_bubble_animated_no_badge:hover{box-shadow:0 5px 24px rgba(0, 0, 0, .3)}.fb_customer_chat_bubble_animated_with_badge{box-shadow:-5px 4px 14px rgba(0, 0, 0, .15);transition:box-shadow 150ms linear}.fb_customer_chat_bubble_animated_with_badge:hover{box-shadow:-5px 8px 24px rgba(0, 0, 0, .2)}.fb_invisible_flow{display:inherit;height:0;overflow-x:hidden;width:0}.fb_new_ui_mobile_overlay_active{overflow:hidden}@keyframes fb_mpn_landing_page_slide_in{0%{border-radius:50%;margin:0 24px;width:60px}40%{border-radius:18px}100%{margin:0 12px;width:100% - 24px}}@keyframes fb_mpn_landing_page_slide_in_from_left{0%{border-radius:50%;left:12px;margin:0 24px;width:60px}40%{border-radius:18px}100%{left:12px;margin:0 12px;width:100% - 24px}}@keyframes fb_mpn_landing_page_slide_out{0%{margin:0 12px;width:100% - 24px}60%{border-radius:18px}100%{border-radius:50%;margin:0 24px;width:60px}}@keyframes fb_mpn_landing_page_slide_out_from_left{0%{left:12px;width:100% - 24px}60%{border-radius:18px}100%{border-radius:50%;left:12px;width:60px}}@keyframes fb_mpn_landing_page_slide_up{0%{bottom:0;opacity:0}100%{bottom:24px;opacity:1}}@keyframes fb_mpn_bounce_in{0%{opacity:.5;top:100%}100%{opacity:1;top:0}}@keyframes fb_mpn_fade_out{0%{bottom:30px;opacity:1}100%{bottom:0;opacity:0}}@keyframes fb_mpn_bounce_out{0%{opacity:1;top:0}100%{opacity:.5;top:100%}}@keyframes fb_bounce_in_v2{0%{opacity:0;transform:scale(0, 0);transform-origin:bottom right}50%{transform:scale(1.03, 1.03);transform-origin:bottom right}100%{opacity:1;transform:scale(1, 1);transform-origin:bottom right}}@keyframes fb_bounce_in_from_left{0%{opacity:0;transform:scale(0, 0);transform-origin:bottom left}50%{transform:scale(1.03, 1.03);transform-origin:bottom left}100%{opacity:1;transform:scale(1, 1);transform-origin:bottom left}}@keyframes fb_bounce_out_v2{0%{opacity:1;transform:scale(1, 1);transform-origin:bottom right}100%{opacity:0;transform:scale(0, 0);transform-origin:bottom right}}@keyframes fb_bounce_out_from_left{0%{opacity:1;transform:scale(1, 1);transform-origin:bottom left}100%{opacity:0;transform:scale(0, 0);transform-origin:bottom left}}@keyframes fb_bounce_out_v2_mobile_chat_started{0%{opacity:1;top:0}100%{opacity:0;top:20px}}@keyframes fb_customer_chat_bubble_bounce_in_animation{0%{bottom:6pt;opacity:0;transform:scale(0, 0);transform-origin:center}70%{bottom:18pt;opacity:1;transform:scale(1.2, 1.2)}100%{transform:scale(1, 1)}}@keyframes slideInFromBottom{0%{opacity:.1;transform:translateY(100%)}100%{opacity:1;transform:translateY(0)}}@keyframes sli ...
# <body class="bodywhite" data-offset="120" data-spy="scroll" data-target=".navbar">
# <header class="fixed-top">
# <div>
# <nav class="navbar navbar-expand-lg navbar-light">
# <a class="navbar-brand" href="https://www.propertiesguru.com/"><img alt="Properties Guru" src="https://www.propertiesguru.com/skin/pg/images/properties-guru-inner-logo.png"/></a>
# <input id="cityid" name="cityid" type="hidden" value="1081"/>
# <input id="cityname" name="cityname" type="hidden" value="New Delhi"/>
# <input id="locationname" name="locationname" type="hidden" value=""/>
# <input id="viewtype" name="viewtype" type="hidden" value="list"/>
# <div class="search-type">
# <div class="select-box">
# <select class="form-control wide" id="popertytype" name="popertytype" style="display: none;">
# <option selected="selected" value="sell">Buy</option>
# <option value="rent">Rent</option>
# </select><div class="nice-select form-control wide" tabindex="0"><span class="current">Buy</span><ul class="list"><li class="option selected" data-value="sell">Buy</li><li class="option" data-value="rent">Rent</li></ul></div>
# </div>
# </div>
# <div class="multi-search">
# <span class="selecteditem"><span class="lc" rel="">New Delhi <i class="fa fa-close"></i></span></span>
# <input class="form-control" id="citylocation" name="citylocation" type="text" value=""/>
# <input id="cityhtml" name="cityhtml" type="hidden" value="new_delhi"/>
# <input id="cathtml" name="cathtml" type="hidden" value="residential_apartment_flat"/>
# <button class="multi-search-btn"><span class="lnr lnr-magnifier"></span></button>
# </div>
# <div class="mobile-panel">
# <ul class="mobile-menu">
# <li><a class="nav-link" href="https://www.propertiesguru.com/listing">List Property</a></li>
# <li class="mobile-user-loged"><a class="nav-link loginmodel" href="javascript:void(0)"><img alt="login my account" class="user-img" height="30" src="https://www.propertiesguru.com/skin/pg/images/agent-img.jpg" width="30"/></a></li>
# </ul>
# </div>
# <div class="collapse navbar-collapse" id="navbarSupportedContent">
# <!--<div class="my-2 my-lg-0">Chennai</div>-->
# <ul class="navbar-nav ml-md-auto">
# <li class="nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" role="button">Buy</a>
# <div class="dropdown-menu dropdown-menu-right">
# <div class="row">
# <div class="col-md-4">
# <h4><span class="reffidtxt">Residential Property</span></h4>
# <div class="dropdown-divider"></div>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_apartment_flat-for-sale-in-new_delhi">Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_studio_apartment-for-sale-in-new_delhi">Studio Apartment in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_service_apartment-for-sale-in-new_delhi">Service Apartment in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_penthouse-for-sale-in-new_delhi">Penthouse in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_villa_house-for-sale-in-new_delhi">Villa / House in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_builder_floor-for-sale-in-new_delhi">Builder Floor in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_independent_floor-for-sale-in-new_delhi">Independent Floor in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_farm_house-for-sale-in-new_delhi">Farm House in New Delhi</a>
# </div>
# <div class="col-md-4">
# <h4>Residential in New Delhi</h4>
# <div class="dropdown-divider"></div>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/1bhk-residential-for-sale-in-new_delhi">											 Buy 1 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/2bhk-residential-for-sale-in-new_delhi">											 Buy 2 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/3bhk-residential-for-sale-in-new_delhi">											 Buy 3 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/4bhk-residential-for-sale-in-new_delhi">											 Buy 4 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/5bhk-residential-for-sale-in-new_delhi">											 Buy 5 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/6bhk-residential-for-sale-in-new_delhi">											 Buy 6 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/7bhk-residential-for-sale-in-new_delhi">											 Buy 7 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/8bhk-residential-for-sale-in-new_delhi">											 Buy 8 BHK Apartment / Flat in New Delhi</a>
# </div>
# <div class="col-md-4">
# <h4>Nearby Localities</h4>
# <div class="dropdown-divider"></div>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-sale-in-surya_enclave_new_delhi">Apartment / Flat in Surya Enclave</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-sale-in-university_of_delhi_north_campus_new_delhi">Apartment / Flat in University of Delhi North...</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-sale-in-ramakrishna_puram_new_delhi">Apartment / Flat in Ramakrishna Puram</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-sale-in-shakurbasti_new_delhi">Apartment / Flat in Shakurbasti</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-sale-in-janta_colony_new_delhi">Apartment / Flat in Janta Colony</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-sale-in-indira_nagar_new_delhi">Apartment / Flat in Indira Nagar</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-sale-in-khera_khurd_new_delhi">Apartment / Flat in Khera Khurd</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-sale-in-mehrauli_badarpur_road_new_delhi">Apartment / Flat in Mehrauli Badarpur Road</a>
# </div>
# </div>
# </div>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" href="#" role="button">Rent
# 							</a>
# <div class="dropdown-menu dropdown-menu-right">
# <div class="row">
# <div class="col-md-4">
# <h4><span class="reffidtxt">Residential</span> Property</h4>
# <div class="dropdown-divider"></div>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_apartment_flat-for-rent-in-new_delhi">Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_studio_apartment-for-rent-in-new_delhi">Studio Apartment in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_service_apartment-for-rent-in-new_delhi">Service Apartment in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_penthouse-for-rent-in-new_delhi">Penthouse in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_villa_house-for-rent-in-new_delhi">Villa / House in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_builder_floor-for-rent-in-new_delhi">Builder Floor in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_independent_floor-for-rent-in-new_delhi">Independent Floor in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/property-search/residential_farm_house-for-rent-in-new_delhi">Farm House in New Delhi</a>
# </div>
# <div class="col-md-4">
# <h4>Residential in New Delhi</h4>
# <div class="dropdown-divider"></div>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/1bhk-residential-for-rent-in-new_delhi">Rent 1 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/2bhk-residential-for-rent-in-new_delhi">Rent 2 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/3bhk-residential-for-rent-in-new_delhi">Rent 3 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/4bhk-residential-for-rent-in-new_delhi">Rent 4 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/5bhk-residential-for-rent-in-new_delhi">Rent 5 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/6bhk-residential-for-rent-in-new_delhi">Rent 6 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/7bhk-residential-for-rent-in-new_delhi">Rent 7 BHK Apartment / Flat in New Delhi</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/residential-search/8bhk-residential-for-rent-in-new_delhi">Rent 8 BHK Apartment / Flat in New Delhi</a>
# </div>
# <div class="col-md-4">
# <h4>Nearby Localities</h4>
# <div class="dropdown-divider"></div>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-rent-in-surya_enclave_new_delhi">Apartment / Flat in Surya Enclave</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-rent-in-university_of_delhi_north_campus_new_delhi">Apartment / Flat in University of Delhi North...</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-rent-in-ramakrishna_puram_new_delhi">Apartment / Flat in Ramakrishna Puram</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-rent-in-shakurbasti_new_delhi">Apartment / Flat in Shakurbasti</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-rent-in-janta_colony_new_delhi">Apartment / Flat in Janta Colony</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-rent-in-indira_nagar_new_delhi">Apartment / Flat in Indira Nagar</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-rent-in-khera_khurd_new_delhi">Apartment / Flat in Khera Khurd</a>
# <a class="dropdown-item" href="https://www.propertiesguru.com/search-property/residential-for-rent-in-mehrauli_badarpur_road_new_delhi">Apartment / Flat in Mehrauli Badarpur Road</a>
# </div>
# </div>
# </div>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="https://www.propertiesguru.com/listing">List Property</a>
# </li>
# <li class="nav-item"><a class="nav-link loginmodel" href="javascript:void(0)"><i aria-hidden="true" class="fa fa-user-o"></i> Login</a></li>
# </ul>
# </div>
# </nav>
# </div>
# </header>
# <div id="mobileheader">
# <div class="container-fluid searchheader header">
# <a href="#"><i class="las la-bars"></i></a>
# <center class="inline">
# <a href="https://www.propertiesguru.com/"><img alt="propertiesguru " class="logo" src="https://www.propertiesguru.com/media/images/mobile-logo2.png"/></a>
# </center>
# <a class="f-right n-decoration list" href="https://www.propertiesguru.com/listing"> List Property <span>FREE</span></a>
# <a href="javascript:void(0);" id="mobilesearchfilters"><i class="search las la-search"></i></a>
# </div>
# </div>
# <nav class="navbar navbar-expand-md navbar-light pg-filter headbar">
# <button aria-controls="navbarNavDropdown" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarNavDropdown" data-toggle="collapse" type="button">Advance Search</button>
# <div class="collapse navbar-collapse" id="navbarNavDropdown">
# <a class="navbar-brand" href="#"><img alt="propertiesguru.com" src="https://www.propertiesguru.com/skin/pg/images/filter-nav-icon.png"/></a>
# <ul class="navbar-nav mr-md-no">
# <li class="nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle cat" data-toggle="dropdown" href="#" id="navbarDropdownMenuLink"><i class="fa fa-check-circle show"></i>Property Type</a>
# <ul aria-labelledby="navbarDropdownMenuLink" class="dropdown-menu form-content category">
# <li>
# <a catid="1" class="dropdown-item dropdown-toggle catreffid1" href="#" html="residential" onclick="$('#cathtml').val('residential');" rel="catreffid1">Residential Property</a>
# <ul class="dropdown-menu show catreffid1">
# <li>
# <div class="negotiable">
# <div class="red-check checkallcat">
# <input class="checkall" id="catid1" name="checkall" type="checkbox" value="-1"/>
# <label for="catid1">All Residential</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input checked="checked" class="catid1" id="reffid3" name="catid[]" rel="1" type="checkbox" value="3,28,29,30"/>
# <label for="reffid3">Apartment / Flat</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid1" id="reffid31" name="catid[]" rel="1" type="checkbox" value="31"/>
# <label for="reffid31">Villa / House</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid1" id="reffid32" name="catid[]" rel="1" type="checkbox" value="32,33"/>
# <label for="reffid32">Builder Floor</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid1" id="reffid35" name="catid[]" rel="1" type="checkbox" value="35"/>
# <label for="reffid35">Farm House</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <a catid="2" class="dropdown-item dropdown-toggle catreffid2" href="#" html="commercial" onclick="$('#cathtml').val('commercial');" rel="catreffid2">Commercial Property</a>
# <ul class="dropdown-menu catreffid2">
# <li>
# <div class="negotiable">
# <div class="red-check checkallcat">
# <input class="checkall" id="catid2" name="checkall" type="checkbox" value="-1"/>
# <label for="catid2">All Commercial</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid2" id="reffid18" name="catid[]" rel="2" type="checkbox" value="18"/>
# <label for="reffid18">Office Space</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid2" id="reffid19" name="catid[]" rel="2" type="checkbox" value="19"/>
# <label for="reffid19">Shop</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid2" id="reffid20" name="catid[]" rel="2" type="checkbox" value="20"/>
# <label for="reffid20">Showroom</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid2" id="reffid21" name="catid[]" rel="2" type="checkbox" value="21"/>
# <label for="reffid21">Retail Space</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li>
# <a catid="4" class="dropdown-item dropdown-toggle catreffid4" href="#" html="landplot" onclick="$('#cathtml').val('landplot');" rel="catreffid4">Land / Plot Property</a>
# <ul class="dropdown-menu catreffid4">
# <li>
# <div class="negotiable">
# <div class="red-check checkallcat">
# <input class="checkall" id="catid4" name="checkall" type="checkbox" value="-1"/>
# <label for="catid4">All Land / Plot</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid4" id="reffid24" name="catid[]" rel="4" type="checkbox" value="24"/>
# <label for="reffid24">Residential Plot</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid4" id="reffid25" name="catid[]" rel="4" type="checkbox" value="25"/>
# <label for="reffid25">Agriculture Land</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid4" id="reffid26" name="catid[]" rel="4" type="checkbox" value="26"/>
# <label for="reffid26">Commercial Plot</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# <li>
# <div class="negotiable">
# <div class="red-check">
# <input class="catid4" id="reffid27" name="catid[]" rel="4" type="checkbox" value="27"/>
# <label for="reffid27">Industrial Land</label>
# <div class="check"></div>
# </div>
# </div>
# </li>
# </ul>
# </li>
# </ul>
# <input id="reffid" name="reffid" type="hidden" value="1"/>
# </li>
# <li class="nav-item dropdown budgetnav">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle bugt" data-toggle="dropdown" href="#" id="navbarDropdownMenuLink"><i class="fa fa-check-circle"></i>Budget</a>
# <ul aria-labelledby="navbarDropdownMenuLink" class="dropdown-menu form-content">
# <li>
# <div class="row no-gutters form-content budget totalbudget">
# <div class="col-6">
# <input class="form-control" id="minbudget" name="minbudget" placeholder="Min" type="text" value=""/>
# </div>
# <div class="col-6">
# <input class="form-control" id="maxbudget" name="maxbudget" placeholder="Max" type="text" value=""/>
# </div>
# </div>
# <div class="row no-gutters form-content budget scroll budget totalbudget">
# <div class="col-6 budgetsell">
# <ul class="min">
# <li><a href="#" rel="0">Min</a></li>
# <li><a class="" href="#" rel="1500000"><span>₹</span>15 Lac</a></li>
# <li><a class="" href="#" rel="2500000"><span>₹</span>25 Lac</a></li>
# <li><a class="" href="#" rel="5000000"><span>₹</span>50 Lac</a></li>
# <li><a class="" href="#" rel="10000000"><span>₹</span>1 Cr</a></li>
# <li><a class="" href="#" rel="15000000"><span>₹</span>1.5 Cr</a></li>
# <li><a class="" href="#" rel="25000000"><span>₹</span>2.5 Cr</a></li>
# <li><a class="" href="#" rel="30000000"><span>₹</span>3 Cr</a></li>
# <li><a class="" href="#" rel="40000000"><span>₹</span>4 Cr</a></li>
# <li><a class="" href="#" rel="50000000"><span>₹</span>5 Cr</a></li>
# <li><a class="" href="#" rel="70000000"><span>₹</span>7 Cr</a></li>
# <li><a class="" href="#" rel="100000000"><span>₹</span>10 Cr</a></li>
# <li><a class="" href="#" rel="200000000"><span>₹</span>20 Cr</a></li>
# </ul>
# </div>
# <div class="col-6 budgetsell">
# <ul class="max">
# <li><a class="" href="#" rel="1500000"><span>₹</span>15 Lac</a></li>
# <li><a class="" href="#" rel="2500000"><span>₹</span>25 Lac</a></li>
# <li><a class="" href="#" rel="5000000"><span>₹</span>50 Lac</a></li>
# <li><a class="" href="#" rel="10000000"><span>₹</span>1 Cr</a></li>
# <li><a class="" href="#" rel="15000000"><span>₹</span>1.5 Cr</a></li>
# <li><a class="" href="#" rel="25000000"><span>₹</span>2.5 Cr</a></li>
# <li><a class="" href="#" rel="30000000"><span>₹</span>3 Cr</a></li>
# <li><a class="" href="#" rel="40000000"><span>₹</span>4 Cr</a></li>
# <li><a class="" href="#" rel="50000000"><span>₹</span>5 Cr</a></li>
# <li><a class="" href="#" rel="70000000"><span>₹</span>7 Cr</a></li>
# <li><a class="" href="#" rel="100000000"><span>₹</span>10 Cr</a></li>
# <li><a class="" href="#" rel="200000000"><span>₹</span>20 Cr</a></li>
# <li><a href="#" rel=""><span>₹</span>Max</a></li>
# </ul>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li class="nav-item dropdown bedroomdropdown show">
# <a aria-expanded="true" aria-haspopup="true" class="nav-link dropdown-toggle bd" data-toggle="dropdown" href="#" id="navbarDropdownMenuLink"><i class="fa fa-check-circle show"></i>BHK</a>
# <ul aria-labelledby="navbarDropdownMenuLink" class="dropdown-menu form-content dropdown-beds show">
# <li>
# <div class="row no-gutters form-content navbads">
# <ul class="property-type room-no pull-right">
# <li>
# <input class="bedroom" id="1" name="rooms-no" type="checkbox" value="1"/>
# <label for="1"><span>1</span></label>
# <div class="check"></div>
# </li>
# <li>
# <input checked="" class="bedroom" id="2" name="rooms-no" type="checkbox" value="2"/>
# <label for="2"><span>2</span></label>
# <div class="check"></div>
# </li>
# <li>
# <input class="bedroom" id="3" name="rooms-no" type="checkbox" value="3"/>
# <label for="3"><span>3</span></label>
# <div class="check"></div>
# </li>
# <li>
# <input class="bedroom" id="4" name="rooms-no" type="checkbox" value="4"/>
# <label for="4"><span>4</span></label>
# <div class="check"></div>
# </li>
# <li>
# <div class="select-box select-text room-box resetdrop">
# <select class="form-control rooom-no wide bedroom" id="select_bed" name="select_bed" style="display: none;">
# <option value="">4+</option>
# <option value="5">5</option>
# <option value="6">6</option>
# <option value="7">7</option>
# <option value="8">8</option>
# <option value="9">9</option>
# <option value="10">10</option>
# </select><div class="nice-select form-control rooom-no wide bedroom" tabindex="0"><span class="current">4+</span><ul class="list"><li class="option selected" data-value="">4+</li><li class="option" data-value="5">5</li><li class="option" data-value="6">6</li><li class="option" data-value="7">7</li><li class="option" data-value="8">8</li><li class="option" data-value="9">9</li><li class="option" data-value="10">10</li></ul></div>
# </div>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# </li>
# <li class="nav-item dropdown areanav">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle ar" data-toggle="dropdown" href="#" id="navbarDropdownMenuLink"><i class="fa fa-check-circle"></i>Area
#
# 				</a>
# <ul aria-labelledby="navbarDropdownMenuLink" class="dropdown-menu form-content">
# <li>
# <div class="row no-gutters form-content budget totalarea">
# <div class="col-6">
# <input class="form-control" id="minarea" name="minarea" placeholder="Min" type="text" value=""/>
# </div>
# <div class="col-6">
# <input class="form-control" id="maxarea" name="maxarea" placeholder="Max" type="text" value=""/>
# </div>
# </div>
# <div class="row no-gutters form-content budget totalarea">
# <div class="col-8 offset-2">
# <div class="select-box resetdrop">
# <select class="form-control wide" id="areatype" name="areatype" style="display: none;">
# <option rel="1" value="Sq Ft.">Sq Ft.</option>
# <option rel="9" value="Sq Yd.">Sq Yd.</option>
# <option rel="10.7639" value="Sq Mtr">Sq Mtr</option>
# <option rel="107639" value="Hectares">Hectares</option>
# <option rel="43560" value="Acres">Acres</option>
# </select><div class="nice-select form-control wide" tabindex="0"><span class="current">Sq Ft.</span><ul class="list"><li class="option selected" data-value="Sq Ft.">Sq Ft.</li><li class="option" data-value="Sq Yd.">Sq Yd.</li><li class="option" data-value="Sq Mtr">Sq Mtr</li><li class="option" data-value="Hectares">Hectares</li><li class="option" data-value="Acres">Acres</li></ul></div>
# </div>
# </div>
# </div>
# <div class="row no-gutters form-content budget scroll totalarea">
# <div class="col-6">
# <ul class="min">
# <li><a class="" href="#" rel="0">Min</a></li>
# <li><a class="" href="#" rel="100">100</a></li>
# <li><a class="" href="#" rel="200">200</a></li>
# <li><a class="" href="#" rel="300">300</a></li>
# <li><a class="" href="#" rel="500">500</a></li>
# <li><a class="" href="#" rel="1000">1000</a></li>
# <li><a class="" href="#" rel="1500">1500</a></li>
# <li><a class="" href="#" rel="2000">2000</a></li>
# <li><a class="" href="#" rel="2500">2500</a></li>
# <li><a class="" href="#" rel="3000">3000</a></li>
# <li><a class="" href="#" rel="4000">4000</a></li>
# <li><a class="" href="#" rel="5000">5000</a></li>
# <li><a class="" href="#" rel="6000">6000</a></li>
# <li><a class="" href="#" rel="7000">7000</a></li>
# <li><a class="" href="#" rel="8000">8000</a></li>
# <li><a class="" href="#" rel="9000">9000</a></li>
# </ul>
# </div>
# <div class="col-6">
# <ul class="max">
# <li><a class="" href="#" rel="100">100</a></li>
# <li><a class="" href="#" rel="200">200</a></li>
# <li><a class="" href="#" rel="300">300</a></li>
# <li><a class="" href="#" rel="500">500</a></li>
# <li><a class="" href="#" rel="1000">1000</a></li>
# <li><a class="" href="#" rel="1500">1500</a></li>
# <li><a class="" href="#" rel="2000">2000</a></li>
# <li><a class="" href="#" rel="2500">2500</a></li>
# <li><a class="" href="#" rel="3000">3000</a></li>
# <li><a class="" href="#" rel="4000">4000</a></li>
# <li><a class="" href="#" rel="5000">5000</a></li>
# <li><a class="" href="#" rel="6000">6000</a></li>
# <li><a class="" href="#" rel="7000">7000</a></li>
# <li><a class="" href="#" rel="8000">8000</a></li>
# <li><a class="" href="#" rel="9000">9000</a></li>
# <li><a class="" href="#" rel="">Max</a></li>
# </ul>
# </div>
# </div>
# </li>
# </ul>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle oh" data-toggle="dropdown" href="#" id="navbarDropdownMenuLink"><i class="fa fa-check-circle"></i>More
#
# 							<i aria-hidden="true" class="fa fa-sliders"></i>
# </a>
# <ul aria-labelledby="navbarDropdownMenuLink" class="dropdown-menu navdropmore form-content">
# <li>
# <div class="row form-content budget navmore">
# <div class="col-12">
# <div class="negotiable">
# <div class="red-check">
# <input id="PropertiesPhotos" name="PropertiesPhotos" type="checkbox" value="Show Properties with Photos only"/>
# <label for="PropertiesPhotos">Show Properties with Photos only</label>
# <div class="check"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="row form-content budget navmore">
# <div class="col-sm-4 furnishing">
# <span class="no-label"></span>
# <div class="floating-label no-margin select-box resetdrop">
# <select class="floating-select wide" id="furnishing" name="furnishing" onclick="this.setAttribute('value', this.value);" style="display: none;" value="">
# <option value="">Any</option>
# <option value="Fully Furnished">Fully Furnished</option>
# <option value="Semi Furnished">Semi Furnished</option>
# <option value="Unfurnished">Unfurnished</option>
# </select><div class="nice-select floating-select wide" tabindex="0"><span class="current">Any</span><ul class="list"><li class="option selected" data-value="">Any</li><li class="option" data-value="Fully Furnished">Fully Furnished</li><li class="option" data-value="Semi Furnished">Semi Furnished</li><li class="option" data-value="Unfurnished">Unfurnished</li></ul></div>
# <label class="filled">Furnishing</label>
# </div>
# </div>
# <div class="col-sm-4 availability">
# <span class="no-label"></span>
# <div class="floating-label no-margin select-box resetdrop">
# <select class="floating-select wide" id="availability" name="availability" onclick="this.setAttribute('value', this.value);" style="display: none;" value="">
# <option value="">Any</option>
# <option value="Ready to Move">Ready to Move</option>
# <option value="Under Construction">Under Construction</option>
# </select><div class="nice-select floating-select wide" tabindex="0"><span class="current">Any</span><ul class="list"><li class="option selected" data-value="">Any</li><li class="option" data-value="Ready to Move">Ready to Move</li><li class="option" data-value="Under Construction">Under Construction</li></ul></div>
# <label class="filled">Availability</label>
# </div>
# </div>
# <div class="col-sm-4 propertyonfloor">
# <span class="no-label"></span>
# <div class="floating-label no-margin select-box resetdrop">
# <select class="floating-select wide" id="propertyonfloor" name="propertyonfloor" onclick="this.setAttribute('value', this.value);" style="display: none;" value="">
# <option value="">Any</option>
# <option value="0">Ground</option>
# <option value="1">1</option>
# <option value="2">2</option>
# <option value="3">3</option>
# <option value="4">4</option>
# <option value="5">5</option>
# <option value="6">6</option>
# <option value="7">7</option>
# <option value="8">8</option>
# <option value="9">9</option>
# <option value="10">10</option>
# <option value="11">11</option>
# <option value="12">12</option>
# <option value="13">13</option>
# <option value="14">14</option>
# <option value="15">15</option>
# <option value="16">16</option>
# <option value="17">17</option>
# <option value="18">18</option>
# <option value="19">19</option>
# <option value="20">20</option>
# <option value="21">21</option>
# <option value="22">22</option>
# <option value="23">23</option>
# <option value="24">24</option>
# <option value="25">25</option>
# <option value="26">26</option>
# <option value="27">27</option>
# <option value="28">28</option>
# <option value="29">29</option>
# <option value="30">30</option>
# <option value="31">31</option>
# <option value="32">32</option>
# <option value="33">33</option>
# <option value="34">34</option>
# <option value="35">35</option>
# <option value="36">36</option>
# <option value="37">37</option>
# <option value="38">38</option>
# <option value="39">39</option>
# <option value="40">40</option>
# <option value="41">41</option>
# <option value="42">42</option>
# <option value="43">43</option>
# <option value="44">44</option>
# <option value="45">45</option>
# <option value="46">46</option>
# <option value="47">47</option>
# <option value="48">48</option>
# <option value="49">49</option>
# <option value="50">50</option>
# <option value="51">51</option>
# <option value="52">52</option>
# <option value="53">53</option>
# <option value="54">54</option>
# <option value="55">55</option>
# <option value="56">56</option>
# <option value="57">57</option>
# <option value="58">58</option>
# <option value="59">59</option>
# <option value="60">60</option>
# <option value="61">61</option>
# <option value="62">62</option>
# <option value="63">63</option>
# <option value="64">64</option>
# <option value="65">65</option>
# <option value="66">66</option>
# <option value="67">67</option>
# <option value="68">68</option>
# <option value="69">69</option>
# <option value="70">70</option>
# <option value="71">71</option>
# <option value="72">72</option>
# <option value="73">73</option>
# <option value="74">74</option>
# <option value="75">75</option>
# <option value="76">76</option>
# <option value="77">77</option>
# <label class="filled">Property Floor</label>
# </div>
# </div>
# ...
# </div>
# <div class="row last1 shadow-lg" id="mobileshortibtn">
# <button class="btn btn-filters1" id="filters1" type="button"><span class="icon-filters"></span> Filters</button>
# <button class="btn btn-sort1" data-target="#sortbymodal" data-toggle="modal" type="button"><span class="icon-sort"></span> Sort By</button>
# </div>
# <div aria-hidden="true" aria-labelledby="sortbymodallabel" class="modal fade" id="sortbymodal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content animate-bottom">
# <div class="modal-header">
# <h6 class="modal-title" id="sortbymodallabel">Sort By</h6>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# </div>
# <div class="modal-body">
# <div class="option">
# <ul>
# <li><a href="javascript:void(0)" rel="">Relevance</a></li>
# <li><a href="javascript:void(0)" rel="sno desc">Most Recent</a></li>
# <li><a href="javascript:void(0)" rel="price asc">Price - Low to High</a></li>
# <li><a href="javascript:void(0)" rel="price desc">Price - High to Low</a></li>
# <li><a href="javascript:void(0)" rel="defaultarea asc">Rate/Sqft - Low to High</a></li>
# <li><a href="javascript:void(0)" rel="defaultarea desc">Rate/Sqft - High to Low</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <footer>
# <div class="container-fluid">
# <div class="footer-menu-block">
# <div>
# <h4>Quick Links</h4>
# <ul class="quick-link">
# <li><a href="https://www.propertiesguru.com/listing">List your property</a></li>
# <li><a href="https://www.propertiesguru.com/search/residential-property-for-sale-in-new_delhi">Properties for Sale</a></li>
# <li><a href="https://www.propertiesguru.com/search/residential-property-for-rent-in-new_delhi">Properties for Rent</a></li>
# <li><a href="https://www.propertiesguru.com/requirement">Post Requirement</a> </li>
# <li><a href="https://www.propertiesguru.com/home-loan">Home Loan</a></li>
# <li><a href="https://www.propertiesguru.com/customer-care">Customer Care</a></li>
# <li><a href="https://blog.propertiesguru.com/" target="_blank">Blog</a></li>
# </ul>
# </div>
# <div>
# <h4>Property in New Delhi</h4>
# <ul>
# <li><a href="https://www.propertiesguru.com/property-search/residential_apartment_flat-for-sale-in-new_delhi">Apartment / Flat in New Delhi</a></li>
# <li><a href="https://www.propertiesguru.com/property-search/residential_studio_apartment-for-sale-in-new_delhi">Studio Apartment in New Delhi</a></li>
# <li><a href="https://www.propertiesguru.com/property-search/residential_service_apartment-for-sale-in-new_delhi">Service Apartment in New Delhi</a></li>
# <li><a href="https://www.propertiesguru.com/property-search/residential_penthouse-for-sale-in-new_delhi">Penthouse in New Delhi</a></li>
# <li><a href="https://www.propertiesguru.com/property-search/residential_villa_house-for-sale-in-new_delhi">Villa / House in New Delhi</a></li>
# <li><a href="https://www.propertiesguru.com/property-search/residential_builder_floor-for-sale-in-new_delhi">Builder Floor in New Delhi</a></li>
# <li><a href="https://www.propertiesguru.com/property-search/residential_independent_floor-for-sale-in-new_delhi">Independent Floor in New Delhi</a></li>
# <li><a href="https://www.propertiesguru.com/property-search/residential_farm_house-for-sale-in-new_delhi">Farm House in New Delhi</a></li>
# <li><a href="https://www.propertiesguru.com/property-search/commercial_office_space-for-sale-in-new_delhi">Office Space in New Delhi</a></li>
# <li><a href="https://www.propertiesguru.com/property-search/commercial_shop-for-sale-in-new_delhi">Shop in New Delhi</a></li>
# <li><a href="https://www.propertiesguru.com/property-search/commercial_showroom-for-sale-in-new_delhi">Showroom in New Delhi</a></li>
# <li><a href="https://www.propertiesguru.com/property-search/commercial_retail_space-for-sale-in-new_delhi">Retail Space in New Delhi</a></li>
# <li><a href="https://www.propertiesguru.com/property-search/landplot_residential_plot-for-sale-in-new_delhi">Residential Plot in New Delhi</a></li>
# <li><a href="https://www.propertiesguru.com/property-search/landplot_agriculture_land-for-sale-in-new_delhi">Agriculture Land in New Delhi</a></li>
# <li><a href="https://www.propertiesguru.com/property-search/landplot_commercial_plot-for-sale-in-new_delhi">Commercial Plot in New Delhi</a></li>
# <li><a href="https://www.propertiesguru.com/property-search/landplot_industrial_land-for-sale-in-new_delhi">Industrial Land in New Delhi</a></li>
# </ul>
# </div>
# <div>
# <h4>Real Estate India</h4>
# <ul>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-ahmedabad">Ahmedabad Real Estate</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-bangalore">Bangalore Real Estate</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-chennai">Chennai Real Estate</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-ghaziabad">Ghaziabad Real Estate</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-gurgaon">Gurgaon Real Estate</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-hyderabad">Hyderabad Real Estate</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-jaipur">Jaipur Real Estate</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-kolkata">Kolkata Real Estate</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-lucknow">Lucknow Real Estate</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-ludhiana">Ludhiana Real Estate</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-mumbai">Mumbai Real Estate</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-new_delhi">New Delhi Real Estate</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-noida">Noida Real Estate</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-pune">Pune Real Estate</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-vadodara">Vadodara Real Estate</a></li>
# </ul>
# </div>
# <div>
# <h4>Buy Property in India</h4>
# <ul>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-ahmedabad">Buy Property in Ahmedabad</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-bangalore">Buy Property in Bangalore</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-chennai">Buy Property in Chennai</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-ghaziabad">Buy Property in Ghaziabad</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-gurgaon">Buy Property in Gurgaon</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-hyderabad">Buy Property in Hyderabad</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-jaipur">Buy Property in Jaipur</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-kolkata">Buy Property in Kolkata</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-lucknow">Buy Property in Lucknow</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-ludhiana">Buy Property in Ludhiana</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-mumbai">Buy Property in Mumbai</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-new_delhi">Buy Property in New Delhi</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-noida">Buy Property in Noida</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-pune">Buy Property in Pune</a></li>
# <li><a href="https://www.propertiesguru.com/search-property/residential-for-sale-in-vadodara">Buy Property in Vadodara</a></li>
# </ul>
# </div>
# <div>
# <h4>Connect With Us</h4>
# <ul>
# <li>Need any help? Write to us at:</li>
# <li><i class="fa fa-envelope-o"></i><a href="mailto:support@propertiesguru.com">support@propertiesguru.com</a></li>
# <div class="social-icons">
# <a class="fa fa-twitter" href="https://twitter.com/propertiesguru2" target="_blank"></a>
# <a class="fa fa-linkedin" href="https://www.linkedin.com/groups/13793163/" target="_blank"></a>
# <a class="fa fa-facebook" href="https://www.facebook.com/propertiesguruindia/" target="_blank"></a>
# </div>
# </ul>
# </div>
# </div>
# <div class="footer-bottom">
# <span>All Rights Reserved. © Copyright 2021 PropertiesGuru.com. <a href="https://www.propertiesguru.com/privacy-policy">Privacy Policy</a> | <a href="https://www.propertiesguru.com/terms-and-conditions">Terms and Conditions</a></span>
# </div>
# <div class="footer-bottom">
# <span><strong>Disclaimer: </strong>Propertiesguru.com (Website owned by: Aashi E-Net Solutions Pvt. Ltd.) is online real estate platform facilitate the property owners / buyers / agents / builders to exchange the general information of real estate project / property details, property types, floor area, location, Map and images etc. The details, so published here been sourced out from multiple sources on “as is” and “as available” on best effort basis. It should not deemed to constitute advertisement, solicitation, invitation to offer, offers to sale by any Property Developer/ Builder/ Agent or any other entity. For more info <a href="https://www.propertiesguru.com/terms-and-conditions#disclaimer">Click here</a>. <!--Propertiesguru.com is not marketing, sales partner or entity of any real estate projects / developer / agents. There is possibility that the property information being provided by the seller / developer may not be complete or correct due to update on regular interval basis. So you are requested to ensure the authenticity and verify / validate the accuracy of a property details from the respective Seller / Builders / Agents. Same can also be checked on RERA website for the respective property project / developer / agents before buying / renting the property. PropertiesGuru.com and its Directors, Employees, Associates neither responsible nor liable for any accuracy for the personal or property information and for action taken cases, cost, expenses incurred by any entity person based on the information given on our website. We reserve the right to add, modify, delete and revoke any information without any notification. So by using our website you agree the disclaimer without any limitation and are solely responsible for any risk or consequences without any recourse to PropertiesGuru.com--></span>
# </div>
# </div>
# </footer>
# <a class="back-to-top" href="javascript:void" id="back-to-top" role="button" style="display: inline;"><i aria-hidden="true" class="fa fa-angle-double-up"></i></a>
# <div class="modal login-signup-modal fade" id="login-signup-modal">
# <div class="modal-dialog modal-md">
# <div class="modal-content">
# </div>
# </div>
# </div>
# <div class="modal contact-modal fade" id="contact-modal">
# <div class="modal-dialog">
# <div class="modal-content">
# <button class="close" data-dismiss="modal" type="button">×</button>
# <div class="modal-body">
# </div>
# </div>
# </div>
# </div>
# <div class="modal alert-modal fade" id="setalert"><div class="modal-dialog"><div class="modal-content"><button class="close" data-dismiss="modal" type="button">×</button><div class="modal-body"></div></div></div></div>
# <script src="https://www.propertiesguru.com/skin/pg/js/jquery-3.2.1.min.js"></script>
# <script src="https://www.propertiesguru.com/skin/pg/js/jquery-ui.js"></script>
# <script src="https://www.propertiesguru.com/skin/pg/js/bootstrap.min.js"></script>
# <script src="https://www.propertiesguru.com/skin/pg/js/bootstrap-select.js"></script>
# <script src="https://www.propertiesguru.com/skin/pg/js/jquery.navScroll.min.js"></script>
# <script src="https://www.propertiesguru.com/skin/pg/js/owl.carousel.min.js"></script>
# <script src="https://www.propertiesguru.com/skin/pg/js/jquery.mCustomScrollbar.concat.min.js"></script>
# <span class="reloadjs"><script src="https://www.propertiesguru.com/skin/pg/js/custom.js"></script></span>
# <script>var basepath = "https://www.propertiesguru.com/", pg="search",steps="";</script>
# <script src="https://www.propertiesguru.com/media/js/login.js"></script>
# <script src="https://www.propertiesguru.com/media/js/mobilesearch.js" type="text/javascript"></script>
# <script>
#
# $(document).on("click",".detailurl",function(){
# 	var lnk = $(this).attr("detailurl");
# 	if(lnk!=""){
# 		if($(window).width() <= 1024) window.location.href=lnk;
# 		else window.open(lnk,'_blank');
# 	}
#
# });
#
# $(document).on("click",".detailurl a",function(e){e.stopPropagation();});
#
# $(document).on('click.bs.dropdown.data-api', '.nav-item.dropdown', function (e) {e.stopPropagation();});
#
# $(document).on("click",".favourite",function(){
#
# 	var obj = $(this);
#
# 	$.ajax({
#
# 		url : "https://www.propertiesguru.com/detail/favourite/" + obj.attr("type")+"/" + obj.attr("rel"),
#
# 		success:function(data){
#
# 			if(data == 0) obj.removeClass("active");
#
# 			else obj.addClass("active");
#
# 		}
#
# 	});
#
# });
#
# $(".footer-menu-block h4").click(function(){
#
# 	//$(".footer-menu-block ul").hide("slow");
#
# 	$(this).closest("div").find("ul").slideToggle('slow');
#
# });
#
# </script>
# <script src="https://www.propertiesguru.com/media/js/jquery.autocomplete.min.js" type="text/javascript"></script>
# <script src="https://www.propertiesguru.com/media/js/popup.js" type="text/javascript"></script><script>
# 			/*$(".getpropertypopup").click(function(){
# 				$.ajax({
# 					url:"https://www.propertiesguru.com/detail/contactus/getpopup?type=property&name=&usertype=&phone=&agentid=&imagename=&propertyid=&reffid=&propertytype=&propertyinfo",
# 					success:function(data){
# 						$("#contact-modal .modal-body").html(data);
# 					}
# 				});
# 			});*/
# 			$('.js-example-basic-single').select2();var rowperpage = 10;</script>
# <script src="https://www.propertiesguru.com/media/js/search.js" type="text/javascript"></script>
# <script async="" defer="" src="https://maps.googleapis.com/maps/api/js?v=3.exp&amp;sensor=false&amp;key=AIzaSyCOZXFhy15WLmP465brkwxZbquO58PMNTY&amp;callback=initMap"></script>
# <div class="modal mapview-modal fade" id="mapview-modal"><div class="modal-dialog modal-md"><div class="modal-content"></div></div></div>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-148384149-1"></script>
# <script>
#
#   window.dataLayer = window.dataLayer || [];
#
#   function gtag(){dataLayer.push(arguments);}
#
#   gtag('js', new Date());
#
#
#
#   gtag('config', 'UA-148384149-1');
#
# </script>
# <div class="fb_reset" id="fb-root"><div style="position: absolute; top: -10000px; width: 0px; height: 0px;"><div></div></div></div></body></html>

# %%
newdf = pd.DataFrame()
for k in newsoup.find_all("div", class_="filter-property-list detailurl"):
    title=k.find("h1", class_="filter-pro-heading").text.split("  ")[0]
    address=k.find("h1", class_="filter-pro-heading").text.split("  ")[1]
    price=k.find("span", class_="price").text
    image=k.find("img")['src']
    area=k.find("div", class_="col-4").text.replace("Area","")
    facing=k.find("div", class_="col-sm-7").find("div", class_="col-3").text.replace("Facing","")
    status=k.find("div", class_="col-sm-7").find("div", class_="col-5").text.replace("Status","")
    contact_name=k.find("div", class_="contact-details").text.split("\n")[1]
    posted=k.find("div", class_="contact-details").text.split("\n")[2].replace("Posted:  ","")
    
    df2 = {'Title': title, 'Address': address, "Price": price, "Area":area, "Facing":facing, 
          'Status':status, "Contact_Name": contact_name, "Posted": posted, "Image":image}
    newdf = newdf.append(df2, ignore_index = True)
newdf
# Out:
#                              Address         Area             Contact_Name  \
# 0     GH 13 Paschim Vihar, New Delhi  1200 Sq Ft.   Harpreet Singh (Admin)
# 1         Dwarka Sector 7, New Delhi  1300 Sq Ft.    Vipul Mehta (Builder)
# 2               Karampura, New Delhi  1581 Sq Ft.  krishna shukla  (Agent)
# 3      New Friends Colony, New Delhi   250 Sq Yd.           Bhasin (Agent)
# 4              Moti Nagar, New Delhi  1581 Sq Ft.  krishna shukla  (Agent)
# 5              Moti Nagar, New Delhi  1581 Sq Ft.  krishna shukla  (Agent)
# 6              Moti Nagar, New Delhi  1600 Sq Ft.  krishna shukla  (Agent)
# 7           Okhla Phase 1, New Delhi  2234 Sq Ft.  krishna shukla  (Agent)
# 8        Delhi Cantonment, New Delhi  1581 Sq Ft.  krishna shukla  (Agent)
# 9  Gurgaon Faridabad Road, New Delhi  1500 Sq Ft.    Harsh Khatter (Agent)
#
#        Facing                                              Image  \
# 0  South-East  https://www.propertiesguru.com/media/images/no...
# 1       North  https://www.propertiesguru.com/media/property/...
# 2  North-East  https://www.propertiesguru.com/media/property/...
# 3  South-East  https://www.propertiesguru.com/media/images/no...
# 4  North-East  https://www.propertiesguru.com/media/property/...
# 5  North-East  https://www.propertiesguru.com/media/property/...
# 6  North-East  https://www.propertiesguru.com/media/property/...
# 7  North-East  https://www.propertiesguru.com/media/property/...
# 8  North-East  https://www.propertiesguru.com/media/property/...
# 9  North-East  https://www.propertiesguru.com/media/property/...
#
#            Posted   Price              Status                            Title
# 0   3 Months  ago   1.7Cr       Ready to Move  3 BHK Apartment / Flat for Sale
# 1   8 Months  ago   85Lac  Under Construction  3 BHK Apartment / Flat for Sale
# 2  10 Months  ago  1.78Cr       Ready to Move  3 BHK Apartment / Flat for Sale
# 3  11 Months  ago   3.5Cr       Ready to Move  3 BHK Apartment / Flat for Sale
# 4     1 Year  ago  1.78Cr       Ready to Move  3 BHK Apartment / Flat for Sale
# 5     1 Year  ago  1.78Cr       Ready to Move  3 BHK Apartment / Flat for Sale
# 6     1 Year  ago  1.88Cr       Ready to Move  3 BHK Apartment / Flat for Sale
# 7     1 Year  ago  4.49Cr  Under Construction  3 BHK Apartment / Flat for Sale
# 8     1 Year  ago  1.78Cr       Ready to Move  3 BHK Apartment / Flat for Sale
# 9     1 Year  ago   85Lac       Ready to Move  3 BHK Apartment / Flat for Sale

# %%
newdf.to_excel("3BHK_Property_Output.xlsx")
